# %% [markdown]
# ## *Data Science Unit 4 Sprint 3 Assignment 1*
#
# # Recurrent Neural Networks and Long Short Term Memory (LSTM)
#
# ![Monkey at a typewriter](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Chimpanzee_seated_at_typewriter.jpg/603px-Chimpanzee_seated_at_typewriter.jpg)
#
# It is said that [**infinite monkeys typing for an infinite amount of time**](https://en.wikipedia.org/wiki/Infinite_monkey_theorem) will eventually type, among other things, the complete works of William Shakespeare. So let's see if we can get there a bit faster, with the power of Recurrent Neural Networks and LSTM.
#
# We will focus specifically on Shakespeare's Sonnets to improve our model's learning ability from the data.

# %%
import random
import sys
import os

import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import LambdaCallback

from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Bidirectional
from tensorflow.keras.layers import LSTM

# %matplotlib inline

# a custom data prep class that we'll be using 
from data_cleaning_toolkit_class import data_cleaning_toolkit

# %% [markdown]
# ### Use request to pull data from a URL
#
# [**Read through the request documentation**](https://requests.readthedocs.io/en/master/user/quickstart/#make-a-request) to learn how to download the Shakespeare Sonnets from the Gutenberg website.
#
# **Protip:** Do not overthink it.

# %%
# download all of Shakespear's Sonnets from the Project Gutenberg website

# here's the link for the sonnets
url_shakespeare_sonnets = "https://www.gutenberg.org/cache/epub/1041/pg1041.txt"

# use request and the url to download all of the sonnets - save the result to `r`



# YOUR CODE HERE
r = requests.get(url_shakespeare_sonnets)

# %%
# move the downloaded text out of the request object - save the result to `raw_text_data`
# hint: take a look at the attributes of `r`
# YOUR CODE HERE
raw_text_data = r.text

# %%
# check the data type of `raw_text_data`
type(raw_text_data)
# Out:
# str

# %% [markdown]
# ### Data Cleaning

# %%
# as usual, we are tasked with cleaning up messy data
# Question: Do you see any characters that we could use to split up the text?
raw_text_data[:3000]
# Out:
# "\ufeffThe Project Gutenberg EBook of Shakespeare's Sonnets, by William Shakespeare\r\n\r\nThis eBook is for the use of anyone anywhere at no cost and with\r\nalmost no restrictions whatsoever.  You may copy it, give it away or\r\nre-use it under the terms of the Project Gutenberg License included\r\nwith this eBook or online at www.gutenberg.org\r\n\r\n\r\nTitle: Shakespeare's Sonnets\r\n\r\nAuthor: William Shakespeare\r\n\r\nPosting Date: April 7, 2014 [EBook #1041]\r\nRelease Date: September, 1997\r\nLast Updated: March 10, 2010\r\n\r\nLanguage: English\r\n\r\n\r\n*** START OF THIS PROJECT GUTENBERG EBOOK SHAKESPEARE'S SONNETS ***\r\n\r\n\r\n\r\n\r\nProduced by Joseph S. Miller and Embry-Riddle Aeronautical\r\nUniversity Library. HTML version by Al Haines.\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nTHE SONNETS\r\n\r\nby William Shakespeare\r\n\r\n\r\n\r\n\r\n  I\r\n\r\n  From fairest creatures we desire increase,\r\n  That thereby beauty's rose might never die,\r\n  But as the riper should by time decease,\r\n  His tender heir might bear his memory:\r\n  But thou, contracted to thine own bright eyes,\r\n  Feed'st thy light's flame with self-substantial fuel,\r\n  Making a famine where abundance lies,\r\n  Thy self thy foe, to thy sweet self too cruel:\r\n  Thou that art now the world's fresh ornament,\r\n  And only herald to the gaudy spring,\r\n  Within thine own bud buriest thy content,\r\n  And tender churl mak'st waste in niggarding:\r\n    Pity the world, or else this glutton be,\r\n    To eat the world's due, by the grave and thee.\r\n\r\n  II\r\n\r\n  When forty winters shall besiege thy brow,\r\n  And dig deep trenches in thy beauty's field,\r\n  Thy youth's proud livery so gazed on now,\r\n  Will be a tatter'd weed of small worth held:\r\n  Then being asked, where all thy beauty lies,\r\n  Where all the treasure of thy lusty days;\r\n  To say, within thine own deep sunken eyes,\r\n  Were an all-eating shame, and thriftless praise.\r\n  How much more praise deserv'd thy beauty's use,\r\n  If thou couldst answer 'This fair child of mine\r\n  Shall sum my count, and make my old excuse,'\r\n  Proving his beauty by succession thine!\r\n    This were to be new made when thou art old,\r\n    And see thy blood warm when thou feel'st it cold.\r\n\r\n  III\r\n\r\n  Look in thy glass and tell the face thou viewest\r\n  Now is the time that face should form another;\r\n  Whose fresh repair if now thou not renewest,\r\n  Thou dost beguile the world, unbless some mother.\r\n  For where is she so fair whose unear'd womb\r\n  Disdains the tillage of thy husbandry?\r\n  Or who is he so fond will be the tomb,\r\n  Of his self-love to stop posterity?\r\n  Thou art thy mother's glass and she in thee\r\n  Calls back the lovely April of her prime;\r\n  So thou through windows of thine age shalt see,\r\n  Despite of wrinkles this thy golden time.\r\n    But if thou live, remember'd not to be,\r\n    Die single and thine image dies with thee.\r\n\r\n  IV\r\n\r\n  Unthrifty loveliness, why dost thou spend\r\n  Upon thy self thy beauty's legacy?\r\n  Nature's bequest gives nothing, but doth lend,\r\n  And being frank she lends to those are free:\r\n  Then, beaut"

# %%
# split the text into lines and save the result to `split_data`
# YOUR CODE HERE
split_data = raw_text_data.split('\n')

# %%
# we need to drop all the boilerplate text (i.e., titles and descriptions) as well as white spaces
# so that we are left with only the sonnets themselves 
split_data[:20]
# Out:
# ["\ufeffThe Project Gutenberg EBook of Shakespeare's Sonnets, by William Shakespeare\r",
#  '\r',
#  'This eBook is for the use of anyone anywhere at no cost and with\r',
#  'almost no restrictions whatsoever.  You may copy it, give it away or\r',
#  're-use it under the terms of the Project Gutenberg License included\r',
#  'with this eBook or online at www.gutenberg.org\r',
#  '\r',
#  '\r',
#  "Title: Shakespeare's Sonnets\r",
#  '\r',
#  'Author: William Shakespeare\r',
#  '\r',
#  'Posting Date: April 7, 2014 [EBook #1041]\r',
#  'Release Date: September, 1997\r',
#  'Last Updated: March 10, 2010\r',
#  '\r',
#  'Language: English\r',
#  '\r',
#  '\r',
#  "*** START OF THIS PROJECT GUTENBERG EBOOK SHAKESPEARE'S SONNETS ***\r"]

# %% [markdown]
# **Use list index slicing to remove the titles and descriptions, so we only have the sonnets.**

# %%
# sonnets exist between these indices 
# titles and descriptions exist outside of these indices

# use index slicing to isolate the sonnet lines - save the result to `sonnets`

# YOUR CODE HERE
sonnets = split_data[45:2661]

# %%
sonnets[-2:]
# Out:
# ['    Came there for cure and this by that I prove,\r',
#  "    Love's fire heats water, water cools not love.\r"]

# %%
# notice how all non-sonnet lines have far fewer characters than the actual sonnet lines?
# well, let's use that observation to filter out all the non-sonnet lines
sonnets[200:240]
# Out:
# ["    And nothing 'gainst Time's scythe can make defence\r",
#  '    Save breed, to brave him when he takes thee hence.\r',
#  '\r',
#  '  XIII\r',
#  '\r',
#  '  O! that you were your self; but, love you are\r',
#  '  No longer yours, than you your self here live:\r',
#  '  Against this coming end you should prepare,\r',
#  '  And your sweet semblance to some other give:\r',
#  '  So should that beauty which you hold in lease\r',
#  '  Find no determination; then you were\r',
#  "  Yourself again, after yourself's decease,\r",
#  '  When your sweet issue your sweet form should bear.\r',
#  '  Who lets so fair a house fall to decay,\r',
#  '  Which husbandry in honour might uphold,\r',
#  "  Against the stormy gusts of winter's day\r",
#  "  And barren rage of death's eternal cold?\r",
#  '    O! none but unthrifts. Dear my love, you know,\r',
#  '    You had a father: let your son say so.\r',
#  '\r',
#  '  XIV\r',
#  '\r',
#  '  Not from the stars do I my judgement pluck;\r',
#  '  And yet methinks I have astronomy,\r',
#  '  But not to tell of good or evil luck,\r',
#  "  Of plagues, of dearths, or seasons' quality;\r",
#  '  Nor can I fortune to brief minutes tell,\r',
#  '  Pointing to each his thunder, rain and wind,\r',
#  '  Or say with princes if it shall go well\r',
#  '  By oft predict that I in heaven find:\r',
#  '  But from thine eyes my knowledge I derive,\r',
#  '  And constant stars in them I read such art\r',
#  "  As 'Truth and beauty shall together thrive,\r",
#  "  If from thyself, to store thou wouldst convert';\r",
#  '    Or else of thee this I prognosticate:\r',
#  "    'Thy end is truth's and beauty's doom and date.'\r",
#  '\r',
#  '  XV\r',
#  '\r',
#  '  When I consider every thing that grows\r']

# %%
# any string with less than n_chars characters will be filtered out - save results to `filtered_sonnets`

# YOUR CODE HERE
filtered_sonnets = [x.strip() for x in sonnets if len(x) > 15]

# %%
# ok - much better!
# but we still need to remove all the punctuation and case normalize the text
filtered_sonnets[2400:]
# Out:
# []

# %% [markdown]
# ### Use Custom Data Cleaning Tool
#
# Use one of the methods in the `data_cleaning_toolkit` to clean your data.
#
# There is an example of this in the guided project.

# %%
# instantiate the data_cleaning_toolkit class - save result to `dctk`

# YOUR CODE HERE
dctk = data_cleaning_toolkit()

# %%
# use data_cleaning_toolkit to remove punctuation and to case normalize - save results to `clean_sonnets`

# YOUR CODE HERE
clean_sonnets = [dctk.clean_data(x) for x in filtered_sonnets]

# %%
# much better!
clean_sonnets
# Out:
# ['from fairest creatures we desire increase',
#  'that thereby beautys rose might never die',
#  'but as the riper should by time decease',
#  'his tender heir might bear his memory',
#  'but thou contracted to thine own bright eyes',
#  'feedst thy lights flame with selfsubstantial fuel',
#  'making a famine where abundance lies',
#  'thy self thy foe to thy sweet self too cruel',
#  'thou that art now the worlds fresh ornament',
#  'and only herald to the gaudy spring',
#  'within thine own bud buriest thy content',
#  'and tender churl makst waste in niggarding',
#  'pity the world or else this glutton be',
#  'to eat the worlds due by the grave and thee',
#  'when forty winters shall besiege thy brow',
#  'and dig deep trenches in thy beautys field',
#  'thy youths proud livery so gazed on now',
#  'will be a tatterd weed of small worth held',
#  'then being asked where all thy beauty lies',
#  'where all the treasure of thy lusty days',
#  'to say within thine own deep sunken eyes',
#  'were an alleating shame and thriftless praise',
#  'how much more praise deservd thy beautys use',
#  'if thou couldst answer this fair child of mine',
#  'shall sum my count and make my old excuse',
#  'proving his beauty by succession thine',
#  'this were to be new made when thou art old',
#  'and see thy blood warm when thou feelst it cold',
#  'look in thy glass and tell the face thou viewest',
#  'now is the time that face should form another',
#  'whose fresh repair if now thou not renewest',
#  'thou dost beguile the world unbless some mother',
#  'for where is she so fair whose uneard womb',
#  'disdains the tillage of thy husbandry',
#  'or who is he so fond will be the tomb',
#  'of his selflove to stop posterity',
#  'thou art thy mothers glass and she in thee',
#  'calls back the lovely april of her prime',
#  'so thou through windows of thine age shalt see',
#  'despite of wrinkles this thy golden time',
#  'but if thou live rememberd not to be',
#  'die single and thine image dies with thee',
#  'unthrifty loveliness why dost thou spend',
#  'upon thy self thy beautys legacy',
#  'natures bequest gives nothing but doth lend',
#  'and being frank she lends to those are free',
#  'then beauteous niggard why dost thou abuse',
#  'the bounteous largess given thee to give',
#  'profitless usurer why dost thou use',
#  'so great a sum of sums yet canst not live',
#  'for having traffic with thy self alone',
#  'thou of thy self thy sweet self dost deceive',
#  'then how when nature calls thee to be gone',
#  'what acceptable audit canst thou leave',
#  'thy unused beauty must be tombed with thee',
#  'which used lives th executor to be',
#  'those hours that with gentle work did frame',
#  'the lovely gaze where every eye doth dwell',
#  'will play the tyrants to the very same',
#  'and that unfair which fairly doth excel',
#  'for neverresting time leads summer on',
#  'to hideous winter and confounds him there',
#  'sap checked with frost and lusty leaves quite gone',
#  'beauty oersnowed and bareness every where',
#  'then were not summers distillation left',
#  'a liquid prisoner pent in walls of glass',
#  'beautys effect with beauty were bereft',
#  'nor it nor no remembrance what it was',
#  'but flowers distilld though they with winter meet',
#  'leese but their show their substance still lives sweet',
#  'then let not winters ragged hand deface',
#  'in thee thy summer ere thou be distilld',
#  'make sweet some vial treasure thou some place',
#  'with beautys treasure ere it be selfkilld',
#  'that use is not forbidden usury',
#  'which happies those that pay the willing loan',
#  'thats for thy self to breed another thee',
#  'or ten times happier be it ten for one',
#  'ten times thy self were happier than thou art',
#  'if ten of thine ten times refigurd thee',
#  'then what could death do if thou shouldst depart',
#  'leaving thee living in posterity',
#  'be not selfwilld for thou art much too fair',
#  'to be deaths conquest and make worms thine heir',
#  'lo in the orient when the gracious light',
#  'lifts up his burning head each under eye',
#  'doth homage to his newappearing sight',
#  'serving with looks his sacred majesty',
#  'and having climbd the steepup heavenly hill',
#  'resembling strong youth in his middle age',
#  'yet mortal looks adore his beauty still',
#  'attending on his golden pilgrimage',
#  'but when from highmost pitch with weary car',
#  'like feeble age he reeleth from the day',
#  'the eyes fore duteous now converted are',
#  'from his low tract and look another way',
#  'so thou thyself outgoing in thy noon',
#  'unlookd on diest unless thou get a son',
#  'music to hear why hearst thou music sadly',
#  'sweets with sweets war not joy delights in joy',
#  'why lovst thou that which thou receivst not gladly',
#  'or else receivst with pleasure thine annoy',
#  'if the true concord of welltuned sounds',
#  'by unions married do offend thine ear',
#  'they do but sweetly chide thee who confounds',
#  'in singleness the parts that thou shouldst bear',
#  'mark how one string sweet husband to another',
#  'strikes each in each by mutual ordering',
#  'resembling sire and child and happy mother',
#  'who all in one one pleasing note do sing',
#  'whose speechless song being many seeming one',
#  'sings this to thee thou single wilt prove none',
#  'is it for fear to wet a widows eye',
#  'that thou consumst thy self in single life',
#  'ah if thou issueless shalt hap to die',
#  'the world will wail thee like a makeless wife',
#  'the world will be thy widow and still weep',
#  'that thou no form of thee hast left behind',
#  'when every private widow well may keep',
#  'by childrens eyes her husbands shape in mind',
#  'look what an unthrift in the world doth spend',
#  'shifts but his place for still the world enjoys it',
#  'but beautys waste hath in the world an end',
#  'and kept unused the user so destroys it',
#  'no love toward others in that bosom sits',
#  'that on himself such murdrous shame commits',
#  'for shame deny that thou bearst love to any',
#  'who for thy self art so unprovident',
#  'grant if thou wilt thou art belovd of many',
#  'but that thou none lovst is most evident',
#  'for thou art so possessd with murderous hate',
#  'that gainst thy self thou stickst not to conspire',
#  'seeking that beauteous roof to ruinate',
#  'which to repair should be thy chief desire',
#  'o change thy thought that i may change my mind',
#  'shall hate be fairer lodgd than gentle love',
#  'be as thy presence is gracious and kind',
#  'or to thyself at least kindhearted prove',
#  'make thee another self for love of me',
#  'that beauty still may live in thine or thee',
#  'as fast as thou shalt wane so fast thou growst',
#  'in one of thine from that which thou departest',
#  'and that fresh blood which youngly thou bestowst',
#  'thou mayst call thine when thou from youth convertest',
#  'herein lives wisdom beauty and increase',
#  'without this folly age and cold decay',
#  'if all were minded so the times should cease',
#  'and threescore year would make the world away',
#  'let those whom nature hath not made for store',
#  'harsh featureless and rude barrenly perish',
#  'look whom she best endowd she gave thee more',
#  'which bounteous gift thou shouldst in bounty cherish',
#  'she carvd thee for her seal and meant thereby',
#  'thou shouldst print more not let that copy die',
#  'when i do count the clock that tells the time',
#  'and see the brave day sunk in hideous night',
#  'when i behold the violet past prime',
#  'and sable curls all silvered oer with white',
#  'when lofty trees i see barren of leaves',
#  'which erst from heat did canopy the herd',
#  'and summers green all girded up in sheaves',
#  'borne on the bier with white and bristly beard',
#  'then of thy beauty do i question make',
#  'that thou among the wastes of time must go',
#  'since sweets and beauties do themselves forsake',
#  'and die as fast as they see others grow',
#  'and nothing gainst times scythe can make defence',
#  'save breed to brave him when he takes thee hence',
#  'o that you were your self but love you are',
#  'no longer yours than you your self here live',
#  'against this coming end you should prepare',
#  'and your sweet semblance to some other give',
#  'so should that beauty which you hold in lease',
#  'find no determination then you were',
#  'yourself again after yourselfs decease',
#  'when your sweet issue your sweet form should bear',
#  'who lets so fair a house fall to decay',
#  'which husbandry in honour might uphold',
#  'against the stormy gusts of winters day',
#  'and barren rage of deaths eternal cold',
#  'o none but unthrifts dear my love you know',
#  'you had a father let your son say so',
#  'not from the stars do i my judgement pluck',
#  'and yet methinks i have astronomy',
#  'but not to tell of good or evil luck',
#  'of plagues of dearths or seasons quality',
#  'nor can i fortune to brief minutes tell',
#  'pointing to each his thunder rain and wind',
#  'or say with princes if it shall go well',
#  'by oft predict that i in heaven find',
#  'but from thine eyes my knowledge i derive',
#  'and constant stars in them i read such art',
#  'as truth and beauty shall together thrive',
#  'if from thyself to store thou wouldst convert',
#  'or else of thee this i prognosticate',
#  'thy end is truths and beautys doom and date',
#  'when i consider every thing that grows',
#  'holds in perfection but a little moment',
#  'that this huge stage presenteth nought but shows',
#  'whereon the stars in secret influence comment',
#  'when i perceive that men as plants increase',
#  'cheered and checked even by the selfsame sky',
#  'vaunt in their youthful sap at height decrease',
#  'and wear their brave state out of memory',
#  'then the conceit of this inconstant stay',
#  'sets you most rich in youth before my sight',
#  'where wasteful time debateth with decay',
#  'to change your day of youth to sullied night',
#  'and all in war with time for love of you',
#  'as he takes from you i engraft you new',
#  'but wherefore do not you a mightier way',
#  'make war upon this bloody tyrant time',
#  'and fortify your self in your decay',
#  'with means more blessed than my barren rhyme',
#  'now stand you on the top of happy hours',
#  'and many maiden gardens yet unset',
#  'with virtuous wish would bear you living flowers',
#  'much liker than your painted counterfeit',
#  'so should the lines of life that life repair',
#  'which this times pencil or my pupil pen',
#  'neither in inward worth nor outward fair',
#  'can make you live your self in eyes of men',
#  'to give away yourself keeps yourself still',
#  'and you must live drawn by your own sweet skill',
#  'who will believe my verse in time to come',
#  'if it were filld with your most high deserts',
#  'though yet heaven knows it is but as a tomb',
#  'which hides your life and shows not half your parts',
#  'if i could write the beauty of your eyes',
#  'and in fresh numbers number all your graces',
#  'the age to come would say this poet lies',
#  'such heavenly touches neer touchd earthly faces',
#  'so should my papers yellowd with their age',
#  'be scornd like old men of less truth than tongue',
#  'and your true rights be termd a poets rage',
#  'and stretched metre of an antique song',
#  'but were some child of yours alive that time',
#  'you should live twicein it and in my rhyme',
#  'shall i compare thee to a summers day',
#  'thou art more lovely and more temperate',
#  'rough winds do shake the darling buds of may',
#  'and summers lease hath all too short a date',
#  'sometime too hot the eye of heaven shines',
#  'and often is his gold complexion dimmd',
#  'and every fair from fair sometime declines',
#  'by chance or natures changing course untrimmd',
#  'but thy eternal summer shall not fade',
#  'nor lose possession of that fair thou owst',
#  'nor shall death brag thou wanderst in his shade',
#  'when in eternal lines to time thou growst',
#  'so long as men can breathe or eyes can see',
#  'so long lives this and this gives life to thee',
#  'devouring time blunt thou the lions paws',
#  'and make the earth devour her own sweet brood',
#  'pluck the keen teeth from the fierce tigers jaws',
#  'and burn the longlivd phoenix in her blood',
#  'make glad and sorry seasons as thou fleets',
#  'and do whateer thou wilt swiftfooted time',
#  'to the wide world and all her fading sweets',
#  'but i forbid thee one most heinous crime',
#  'o carve not with thy hours my loves fair brow',
#  'nor draw no lines there with thine antique pen',
#  'him in thy course untainted do allow',
#  'for beautys pattern to succeeding men',
#  'yet do thy worst old time despite thy wrong',
#  'my love shall in my verse ever live young',
#  'a womans face with natures own hand painted',
#  'hast thou the master mistress of my passion',
#  'a womans gentle heart but not acquainted',
#  'with shifting change as is false womens fashion',
#  'an eye more bright than theirs less false in rolling',
#  'gilding the object whereupon it gazeth',
#  'a man in hue all hues in his controlling',
#  'which steals mens eyes and womens souls amazeth',
#  'and for a woman wert thou first created',
#  'till nature as she wrought thee fell adoting',
#  'and by addition me of thee defeated',
#  'by adding one thing to my purpose nothing',
#  'but since she prickd thee out for womens pleasure',
#  'mine be thy love and thy loves use their treasure',
#  'so is it not with me as with that muse',
#  'stirrd by a painted beauty to his verse',
#  'who heaven itself for ornament doth use',
#  'and every fair with his fair doth rehearse',
#  'making a couplement of proud compare',
#  'with sun and moon with earth and seas rich gems',
#  'with aprils firstborn flowers and all things rare',
#  'that heavens air in this huge rondure hems',
#  'o let me true in love but truly write',
#  'and then believe me my love is as fair',
#  'as any mothers child though not so bright',
#  'as those gold candles fixd in heavens air',
#  'let them say more that like of hearsay well',
#  'i will not praise that purpose not to sell',
#  'my glass shall not persuade me i am old',
#  'so long as youth and thou are of one date',
#  'but when in thee times furrows i behold',
#  'then look i death my days should expiate',
#  'for all that beauty that doth cover thee',
#  'is but the seemly raiment of my heart',
#  'which in thy breast doth live as thine in me',
#  'how can i then be elder than thou art',
#  'o therefore love be of thyself so wary',
#  'as i not for myself but for thee will',
#  'bearing thy heart which i will keep so chary',
#  'as tender nurse her babe from faring ill',
#  'presume not on thy heart when mine is slain',
#  'thou gavst me thine not to give back again',
#  'as an unperfect actor on the stage',
#  'who with his fear is put beside his part',
#  'or some fierce thing replete with too much rage',
#  'whose strengths abundance weakens his own heart',
#  'so i for fear of trust forget to say',
#  'the perfect ceremony of loves rite',
#  'and in mine own loves strength seem to decay',
#  'oerchargd with burthen of mine own loves might',
#  'o let my looks be then the eloquence',
#  'and dumb presagers of my speaking breast',
#  'who plead for love and look for recompense',
#  'more than that tongue that more hath more expressd',
#  'o learn to read what silent love hath writ',
#  'to hear with eyes belongs to loves fine wit',
#  'mine eye hath playd the painter and hath stelld',
#  'thy beautys form in table of my heart',
#  'my body is the frame wherein tis held',
#  'and perspective it is best painters art',
#  'for through the painter must you see his skill',
#  'to find where your true image picturd lies',
#  'which in my bosoms shop is hanging still',
#  'that hath his windows glazed with thine eyes',
#  'now see what good turns eyes for eyes have done',
#  'mine eyes have drawn thy shape and thine for me',
#  'are windows to my breast wherethrough the sun',
#  'delights to peep to gaze therein on thee',
#  'yet eyes this cunning want to grace their art',
#  'they draw but what they see know not the heart',
#  'let those who are in favour with their stars',
#  'of public honour and proud titles boast',
#  'whilst i whom fortune of such triumph bars',
#  'unlookd for joy in that i honour most',
#  'great princes favourites their fair leaves spread',
#  'but as the marigold at the suns eye',
#  'and in themselves their pride lies buried',
#  'for at a frown they in their glory die',
#  'the painful warrior famoused for fight',
#  'after a thousand victories once foild',
#  'is from the book of honour razed quite',
#  'and all the rest forgot for which he toild',
#  'then happy i that love and am belovd',
#  'where i may not remove nor be removd',
#  'lord of my love to whom in vassalage',
#  'thy merit hath my duty strongly knit',
#  'to thee i send this written embassage',
#  'to witness duty not to show my wit',
#  'duty so great which wit so poor as mine',
#  'may make seem bare in wanting words to show it',
#  'but that i hope some good conceit of thine',
#  'in thy souls thought all naked will bestow it',
#  'till whatsoever star that guides my moving',
#  'points on me graciously with fair aspect',
#  'and puts apparel on my tatterd loving',
#  'to show me worthy of thy sweet respect',
#  'then may i dare to boast how i do love thee',
#  'till then not show my head where thou mayst prove me',
#  'weary with toil i haste me to my bed',
#  'the dear respose for limbs with travel tird',
#  'but then begins a journey in my head',
#  'to work my mind when bodys works expired',
#  'for then my thoughtsfrom far where i abide',
#  'intend a zealous pilgrimage to thee',
#  'and keep my drooping eyelids open wide',
#  'looking on darkness which the blind do see',
#  'save that my souls imaginary sight',
#  'presents thy shadow to my sightless view',
#  'which like a jewel hung in ghastly night',
#  'makes black night beauteous and her old face new',
#  'lo thus by day my limbs by night my mind',
#  'for thee and for myself no quiet find',
#  'how can i then return in happy plight',
#  'that am debarred the benefit of rest',
#  'when days oppression is not easd by night',
#  'but day by night and night by day oppressd',
#  'and each though enemies to eithers reign',
#  'do in consent shake hands to torture me',
#  'the one by toil the other to complain',
#  'how far i toil still farther off from thee',
#  'i tell the day to please him thou art bright',
#  'and dost him grace when clouds do blot the heaven',
#  'so flatter i the swartcomplexiond night',
#  'when sparkling stars twire not thou gildst the even',
#  'but day doth daily draw my sorrows longer',
#  'and night doth nightly make griefs length seem stronger',
#  'when in disgrace with fortune and mens eyes',
#  'i all alone beweep my outcast state',
#  'and trouble deaf heaven with my bootless cries',
#  'and look upon myself and curse my fate',
#  'wishing me like to one more rich in hope',
#  'featurd like him like him with friends possessd',
#  'desiring this mans art and that mans scope',
#  'with what i most enjoy contented least',
#  'yet in these thoughts my self almost despising',
#  'haply i think on thee and then my state',
#  'like to the lark at break of day arising',
#  'from sullen earth sings hymns at heavens gate',
#  'for thy sweet love rememberd such wealth brings',
#  'that then i scorn to change my state with kings',
#  'when to the sessions of sweet silent thought',
#  'i summon up remembrance of things past',
#  'i sigh the lack of many a thing i sought',
#  'and with old woes new wail my dear times waste',
#  'then can i drown an eye unused to flow',
#  'for precious friends hid in deaths dateless night',
#  'and weep afresh loves long since cancelld woe',
#  'and moan the expense of many a vanishd sight',
#  'then can i grieve at grievances foregone',
#  'and heavily from woe to woe tell oer',
#  'the sad account of forebemoaned moan',
#  'which i new pay as if not paid before',
#  'but if the while i think on thee dear friend',
#  'all losses are restord and sorrows end',
#  'thy bosom is endeared with all hearts',
#  'which i by lacking have supposed dead',
#  'and there reigns love and all loves loving parts',
#  'and all those friends which i thought buried',
#  'how many a holy and obsequious tear',
#  'hath dear religious love stoln from mine eye',
#  'as interest of the dead which now appear',
#  'but things removd that hidden in thee lie',
#  'thou art the grave where buried love doth live',
#  'hung with the trophies of my lovers gone',
#  'who all their parts of me to thee did give',
#  'that due of many now is thine alone',
#  'their images i lovd i view in thee',
#  'and thouall theyhast all the all of me',
#  'if thou survive my wellcontented day',
#  'when that churl death my bones with dust shall cover',
#  'and shalt by fortune once more resurvey',
#  'these poor rude lines of thy deceased lover',
#  'compare them with the bettring of the time',
#  'and though they be outstrippd by every pen',
#  'reserve them for my love not for their rhyme',
#  'exceeded by the height of happier men',
#  'o then vouchsafe me but this loving thought',
#  'had my friends muse grown with this growing age',
#  'a dearer birth than this his love had brought',
#  'to march in ranks of better equipage',
#  'but since he died and poets better prove',
#  'theirs for their style ill read his for his love',
#  'full many a glorious morning have i seen',
#  'flatter the mountain tops with sovereign eye',
#  'kissing with golden face the meadows green',
#  'gilding pale streams with heavenly alchemy',
#  'anon permit the basest clouds to ride',
#  'with ugly rack on his celestial face',
#  'and from the forlorn world his visage hide',
#  'stealing unseen to west with this disgrace',
#  'even so my sun one early morn did shine',
#  'with all triumphant splendour on my brow',
#  'but out alack he was but one hour mine',
#  'the region cloud hath maskd him from me now',
#  'yet him for this my love no whit disdaineth',
#  'suns of the world may stain when heavens sun staineth',
#  'why didst thou promise such a beauteous day',
#  'and make me travel forth without my cloak',
#  'to let base clouds oertake me in my way',
#  'hiding thy bravery in their rotten smoke',
#  'tis not enough that through the cloud thou break',
#  'to dry the rain on my stormbeaten face',
#  'for no man well of such a salve can speak',
#  'that heals the wound and cures not the disgrace',
#  'nor can thy shame give physic to my grief',
#  'though thou repent yet i have still the loss',
#  'the offenders sorrow lends but weak relief',
#  'to him that bears the strong offences cross',
#  'ah but those tears are pearl which thy love sheds',
#  'and they are rich and ransom all ill deeds',
#  'no more be grievd at that which thou hast done',
#  'roses have thorns and silver fountains mud',
#  'clouds and eclipses stain both moon and sun',
#  'and loathsome canker lives in sweetest bud',
#  'all men make faults and even i in this',
#  'authorizing thy trespass with compare',
#  'myself corrupting salving thy amiss',
#  'excusing thy sins more than thy sins are',
#  'for to thy sensual fault i bring in sense',
#  'thy adverse party is thy advocate',
#  'and gainst myself a lawful plea commence',
#  'such civil war is in my love and hate',
#  'that i an accessary needs must be',
#  'to that sweet thief which sourly robs from me',
#  'let me confess that we two must be twain',
#  'although our undivided loves are one',
#  'so shall those blots that do with me remain',
#  'without thy help by me be borne alone',
#  'in our two loves there is but one respect',
#  'though in our lives a separable spite',
#  'which though it alter not loves sole effect',
#  'yet doth it steal sweet hours from loves delight',
#  'i may not evermore acknowledge thee',
#  'lest my bewailed guilt should do thee shame',
#  'nor thou with public kindness honour me',
#  'unless thou take that honour from thy name',
#  'but do not so i love thee in such sort',
#  'as thou being mine mine is thy good report',
#  'as a decrepit father takes delight',
#  'to see his active child do deeds of youth',
#  'so i made lame by fortunes dearest spite',
#  'take all my comfort of thy worth and truth',
#  'for whether beauty birth or wealth or wit',
#  'or any of these all or all or more',
#  'entitled in thy parts do crowned sit',
#  'i make my love engrafted to this store',
#  'so then i am not lame poor nor despisd',
#  'whilst that this shadow doth such substance give',
#  'that i in thy abundance am sufficd',
#  'and by a part of all thy glory live',
#  'look what is best that best i wish in thee',
#  'this wish i have then ten times happy me',
#  'how can my muse want subject to invent',
#  'while thou dost breathe that pourst into my verse',
#  'thine own sweet argument too excellent',
#  'for every vulgar paper to rehearse',
#  'o give thy self the thanks if aught in me',
#  'worthy perusal stand against thy sight',
#  'for whos so dumb that cannot write to thee',
#  'when thou thy self dost give invention light',
#  'be thou the tenth muse ten times more in worth',
#  'than those old nine which rhymers invocate',
#  'and he that calls on thee let him bring forth',
#  'eternal numbers to outlive long date',
#  'if my slight muse do please these curious days',
#  'the pain be mine but thine shall be the praise',
#  'o how thy worth with manners may i sing',
#  'when thou art all the better part of me',
#  'what can mine own praise to mine own self bring',
#  'and what ist but mine own when i praise thee',
#  'even for this let us divided live',
#  'and our dear love lose name of single one',
#  'that by this separation i may give',
#  'that due to thee which thou deservst alone',
#  'o absence what a torment wouldst thou prove',
#  'were it not thy sour leisure gave sweet leave',
#  'to entertain the time with thoughts of love',
#  'which time and thoughts so sweetly doth deceive',
#  'and that thou teachest how to make one twain',
#  'by praising him here who doth hence remain',
#  'take all my loves my love yea take them all',
#  'what hast thou then more than thou hadst before',
#  'no love my love that thou mayst true love call',
#  'all mine was thine before thou hadst this more',
#  'then if for my love thou my love receivest',
#  'i cannot blame thee for my love thou usest',
#  'but yet be blamd if thou thy self deceivest',
#  'by wilful taste of what thyself refusest',
#  'i do forgive thy robbery gentle thief',
#  'although thou steal thee all my poverty',
#  'and yet love knows it is a greater grief',
#  'to bear loves wrong than hates known injury',
#  'lascivious grace in whom all ill well shows',
#  'kill me with spites yet we must not be foes',
#  'those pretty wrongs that liberty commits',
#  'when i am sometime absent from thy heart',
#  'thy beauty and thy years full well befits',
#  'for still temptation follows where thou art',
#  'gentle thou art and therefore to be won',
#  'beauteous thou art therefore to be assaild',
#  'and when a woman woos what womans son',
#  'will sourly leave her till he have prevaild',
#  'ay me but yet thou mightst my seat forbear',
#  'and chide thy beauty and thy straying youth',
#  'who lead thee in their riot even there',
#  'where thou art forced to break a twofold truth',
#  'hers by thy beauty tempting her to thee',
#  'thine by thy beauty being false to me',
#  'that thou hast her it is not all my grief',
#  'and yet it may be said i loved her dearly',
#  'that she hath thee is of my wailing chief',
#  'a loss in love that touches me more nearly',
#  'loving offenders thus i will excuse ye',
#  'thou dost love her because thou knowst i love her',
#  'and for my sake even so doth she abuse me',
#  'suffering my friend for my sake to approve her',
#  'if i lose thee my loss is my loves gain',
#  'and losing her my friend hath found that loss',
#  'both find each other and i lose both twain',
#  'and both for my sake lay on me this cross',
#  'but heres the joy my friend and i are one',
#  'sweet flattery then she loves but me alone',
#  'when most i wink then do mine eyes best see',
#  'for all the day they view things unrespected',
#  'but when i sleep in dreams they look on thee',
#  'and darkly bright are bright in dark directed',
#  'then thou whose shadow shadows doth make bright',
#  'how would thy shadows form form happy show',
#  'to the clear day with thy much clearer light',
#  'when to unseeing eyes thy shade shines so',
#  'how would i say mine eyes be blessed made',
#  'by looking on thee in the living day',
#  'when in dead night thy fair imperfect shade',
#  'through heavy sleep on sightless eyes doth stay',
#  'all days are nights to see till i see thee',
#  'and nights bright days when dreams do show thee me',
#  'if the dull substance of my flesh were thought',
#  'injurious distance should not stop my way',
#  'for then despite of space i would be brought',
#  'from limits far remote where thou dost stay',
#  'no matter then although my foot did stand',
#  'upon the farthest earth removd from thee',
#  'for nimble thought can jump both sea and land',
#  'as soon as think the place where he would be',
#  'but ah thought kills me that i am not thought',
#  'to leap large lengths of miles when thou art gone',
#  'but that so much of earth and water wrought',
#  'i must attend times leisure with my moan',
#  'receiving nought by elements so slow',
#  'but heavy tears badges of eithers woe',
#  'the other two slight air and purging fire',
#  'are both with thee wherever i abide',
#  'the first my thought the other my desire',
#  'these presentabsent with swift motion slide',
#  'for when these quicker elements are gone',
#  'in tender embassy of love to thee',
#  'my life being made of four with two alone',
#  'sinks down to death oppressd with melancholy',
#  'until lifes composition be recurd',
#  'by those swift messengers returnd from thee',
#  'who even but now come back again assurd',
#  'of thy fair health recounting it to me',
#  'this told i joy but then no longer glad',
#  'i send them back again and straight grow sad',
#  'mine eye and heart are at a mortal war',
#  'how to divide the conquest of thy sight',
#  'mine eye my heart thy pictures sight would bar',
#  'my heart mine eye the freedom of that right',
#  'my heart doth plead that thou in him dost lie',
#  'a closet never piercd with crystal eyes',
#  'but the defendant doth that plea deny',
#  'and says in him thy fair appearance lies',
#  'to side this title is impannelled',
#  'a quest of thoughts all tenants to the heart',
#  'and by their verdict is determined',
#  'the clear eyes moiety and the dear hearts part',
#  'as thus mine eyes due is thy outward part',
#  'and my hearts right thy inward love of heart',
#  'betwixt mine eye and heart a league is took',
#  'and each doth good turns now unto the other',
#  'when that mine eye is famishd for a look',
#  'or heart in love with sighs himself doth smother',
#  'with my loves picture then my eye doth feast',
#  'and to the painted banquet bids my heart',
#  'another time mine eye is my hearts guest',
#  'and in his thoughts of love doth share a part',
#  'so either by thy picture or my love',
#  'thy self away art present still with me',
#  'for thou not farther than my thoughts canst move',
#  'and i am still with them and they with thee',
#  'or if they sleep thy picture in my sight',
#  'awakes my heart to hearts and eyes delight',
#  'how careful was i when i took my way',
#  'each trifle under truest bars to thrust',
#  'that to my use it might unused stay',
#  'from hands of falsehood in sure wards of trust',
#  'but thou to whom my jewels trifles are',
#  'most worthy comfort now my greatest grief',
#  'thou best of dearest and mine only care',
#  'art left the prey of every vulgar thief',
#  'thee have i not lockd up in any chest',
#  'save where thou art not though i feel thou art',
#  'within the gentle closure of my breast',
#  'from whence at pleasure thou mayst come and part',
#  'and even thence thou wilt be stoln i fear',
#  'for truth proves thievish for a prize so dear',
#  'against that time if ever that time come',
#  'when i shall see thee frown on my defects',
#  'when as thy love hath cast his utmost sum',
#  'calld to that audit by advisd respects',
#  'against that time when thou shalt strangely pass',
#  'and scarcely greet me with that sun thine eye',
#  'when love converted from the thing it was',
#  'shall reasons find of settled gravity',
#  'against that time do i ensconce me here',
#  'within the knowledge of mine own desert',
#  'and this my hand against my self uprear',
#  'to guard the lawful reasons on thy part',
#  'to leave poor me thou hast the strength of laws',
#  'since why to love i can allege no cause',
#  'how heavy do i journey on the way',
#  'when what i seek my weary travels end',
#  'doth teach that ease and that repose to say',
#  'thus far the miles are measured from thy friend',
#  'the beast that bears me tired with my woe',
#  'plods dully on to bear that weight in me',
#  'as if by some instinct the wretch did know',
#  'his rider lovd not speed being made from thee',
#  'the bloody spur cannot provoke him on',
#  'that sometimes anger thrusts into his hide',
#  'which heavily he answers with a groan',
#  'more sharp to me than spurring to his side',
#  'for that same groan doth put this in my mind',
#  'my grief lies onward and my joy behind',
#  'thus can my love excuse the slow offence',
#  'of my dull bearer when from thee i speed',
#  'from where thou art why should i haste me thence',
#  'till i return of posting is no need',
#  'o what excuse will my poor beast then find',
#  'when swift extremity can seem but slow',
#  'then should i spur though mounted on the wind',
#  'in winged speed no motion shall i know',
#  'then can no horse with my desire keep pace',
#  'therefore desire of perfectst love being made',
#  'shall neighno dull fleshin his fiery race',
#  'but love for love thus shall excuse my jade',
#  'since from thee going he went wilfulslow',
#  'towards thee ill run and give him leave to go',
#  'so am i as the rich whose blessed key',
#  'can bring him to his sweet uplocked treasure',
#  'the which he will not every hour survey',
#  'for blunting the fine point of seldom pleasure',
#  'therefore are feasts so solemn and so rare',
#  'since seldom coming in that long year set',
#  'like stones of worth they thinly placed are',
#  'or captain jewels in the carcanet',
#  'so is the time that keeps you as my chest',
#  'or as the wardrobe which the robe doth hide',
#  'to make some special instant specialblest',
#  'by new unfolding his imprisond pride',
#  'blessed are you whose worthiness gives scope',
#  'being had to triumph being lacked to hope',
#  'what is your substance whereof are you made',
#  'that millions of strange shadows on you tend',
#  'since every one hath every one one shade',
#  'and you but one can every shadow lend',
#  'describe adonis and the counterfeit',
#  'is poorly imitated after you',
#  'on helens cheek all art of beauty set',
#  'and you in grecian tires are painted new',
#  'speak of the spring and foison of the year',
#  'the one doth shadow of your beauty show',
#  'the other as your bounty doth appear',
#  'and you in every blessed shape we know',
#  'in all external grace you have some part',
#  'but you like none none you for constant heart',
#  'o how much more doth beauty beauteous seem',
#  'by that sweet ornament which truth doth give',
#  'the rose looks fair but fairer we it deem',
#  'for that sweet odour which doth in it live',
#  'the canker blooms have full as deep a dye',
#  'as the perfumed tincture of the roses',
#  'hang on such thorns and play as wantonly',
#  'when summers breath their masked buds discloses',
#  'but for their virtue only is their show',
#  'they live unwood and unrespected fade',
#  'die to themselves sweet roses do not so',
#  'of their sweet deaths are sweetest odours made',
#  'and so of you beauteous and lovely youth',
#  'when that shall vade by verse distills your truth',
#  'not marble nor the gilded monuments',
#  'of princes shall outlive this powerful rhyme',
#  'but you shall shine more bright in these contents',
#  'than unswept stone besmeard with sluttish time',
#  'when wasteful war shall statues overturn',
#  'and broils root out the work of masonry',
#  'nor mars his sword nor wars quick fire shall burn',
#  'the living record of your memory',
#  'gainst death and alloblivious enmity',
#  'shall you pace forth your praise shall still find room',
#  'even in the eyes of all posterity',
#  'that wear this world out to the ending doom',
#  'so till the judgment that yourself arise',
#  'you live in this and dwell in lovers eyes',
#  'sweet love renew thy force be it not said',
#  'thy edge should blunter be than appetite',
#  'which but today by feeding is allayd',
#  'tomorrow sharpened in his former might',
#  'so love be thou although today thou fill',
#  'thy hungry eyes even till they wink with fulness',
#  'tomorrow see again and do not kill',
#  'the spirit of love with a perpetual dulness',
#  'let this sad interim like the ocean be',
#  'which parts the shore where two contracted new',
#  'come daily to the banks that when they see',
#  'return of love more blest may be the view',
#  'or call it winter which being full of care',
#  'makes summers welcome thrice more wished more rare',
#  'being your slave what should i do but tend',
#  'upon the hours and times of your desire',
#  'i have no precious time at all to spend',
#  'nor services to do till you require',
#  'nor dare i chide the worldwithoutend hour',
#  'whilst i my sovereign watch the clock for you',
#  'nor think the bitterness of absence sour',
#  'when you have bid your servant once adieu',
#  'nor dare i question with my jealous thought',
#  'where you may be or your affairs suppose',
#  'but like a sad slave stay and think of nought',
#  'save where you are how happy you make those',
#  'so true a fool is love that in your will',
#  'though you do anything he thinks no ill',
#  'that god forbid that made me first your slave',
#  'i should in thought control your times of pleasure',
#  'or at your hand the account of hours to crave',
#  'being your vassal bound to stay your leisure',
#  'o let me suffer being at your beck',
#  'the imprisond absence of your liberty',
#  'and patience tame to sufferance bide each check',
#  'without accusing you of injury',
#  'be where you list your charter is so strong',
#  'that you yourself may privilage your time',
#  'to what you will to you it doth belong',
#  'yourself to pardon of selfdoing crime',
#  'i am to wait though waiting so be hell',
#  'not blame your pleasure be it ill or well',
#  'if there be nothing new but that which is',
#  'hath been before how are our brains beguild',
#  'which labouring for invention bear amiss',
#  'the second burthen of a former child',
#  'o that record could with a backward look',
#  'even of five hundred courses of the sun',
#  'show me your image in some antique book',
#  'since mind at first in character was done',
#  'that i might see what the old world could say',
#  'to this composed wonder of your frame',
#  'whr we are mended or whr better they',
#  'or whether revolution be the same',
#  'o sure i am the wits of former days',
#  'to subjects worse have given admiring praise',
#  'like as the waves make towards the pebbled shore',
#  'so do our minutes hasten to their end',
#  'each changing place with that which goes before',
#  'in sequent toil all forwards do contend',
#  'nativity once in the main of light',
#  'crawls to maturity wherewith being crownd',
#  'crooked eclipses gainst his glory fight',
#  'and time that gave doth now his gift confound',
#  'time doth transfix the flourish set on youth',
#  'and delves the parallels in beautys brow',
#  'feeds on the rarities of natures truth',
#  'and nothing stands but for his scythe to mow',
#  'and yet to times in hope my verse shall stand',
#  'praising thy worth despite his cruel hand',
#  'is it thy will thy image should keep open',
#  'my heavy eyelids to the weary night',
#  'dost thou desire my slumbers should be broken',
#  'while shadows like to thee do mock my sight',
#  'is it thy spirit that thou sendst from thee',
#  'so far from home into my deeds to pry',
#  'to find out shames and idle hours in me',
#  'the scope and tenure of thy jealousy',
#  'o no thy love though much is not so great',
#  'it is my love that keeps mine eye awake',
#  'mine own true love that doth my rest defeat',
#  'to play the watchman ever for thy sake',
#  'for thee watch i whilst thou dost wake elsewhere',
#  'from me far off with others all too near',
#  'sin of selflove possesseth all mine eye',
#  'and all my soul and all my every part',
#  'and for this sin there is no remedy',
#  'it is so grounded inward in my heart',
#  'methinks no face so gracious is as mine',
#  'no shape so true no truth of such account',
#  'and for myself mine own worth do define',
#  'as i all other in all worths surmount',
#  'but when my glass shows me myself indeed',
#  'beated and choppd with tanned antiquity',
#  'mine own selflove quite contrary i read',
#  'self so selfloving were iniquity',
#  'tis theemyselfthat for myself i praise',
#  'painting my age with beauty of thy days',
#  'against my love shall be as i am now',
#  'with times injurious hand crushd and oerworn',
#  'when hours have draind his blood and filld his brow',
#  'with lines and wrinkles when his youthful morn',
#  'hath travelld on to ages steepy night',
#  'and all those beauties whereof now hes king',
#  'are vanishing or vanished out of sight',
#  'stealing away the treasure of his spring',
#  'for such a time do i now fortify',
#  'against confounding ages cruel knife',
#  'that he shall never cut from memory',
#  'my sweet loves beauty though my lovers life',
#  'his beauty shall in these black lines be seen',
#  'and they shall live and he in them still green',
#  'when i have seen by times fell hand defacd',
#  'the richproud cost of outworn buried age',
#  'when sometime lofty towers i see downrazd',
#  'and brass eternal slave to mortal rage',
#  'when i have seen the hungry ocean gain',
#  'advantage on the kingdom of the shore',
#  'and the firm soil win of the watery main',
#  'increasing store with loss and loss with store',
#  'when i have seen such interchange of state',
#  'or state itself confounded to decay',
#  'ruin hath taught me thus to ruminate',
#  'that time will come and take my love away',
#  'this thought is as a death which cannot choose',
#  'but weep to have that which it fears to lose',
#  'since brass nor stone nor earth nor boundless sea',
#  'but sad mortality oersways their power',
#  'how with this rage shall beauty hold a plea',
#  'whose action is no stronger than a flower',
#  'o how shall summers honey breath hold out',
#  'against the wrackful siege of battering days',
#  'when rocks impregnable are not so stout',
#  'nor gates of steel so strong but time decays',
#  'o fearful meditation where alack',
#  'shall times best jewel from times chest lie hid',
#  'or what strong hand can hold his swift foot back',
#  'or who his spoil of beauty can forbid',
#  'o none unless this miracle have might',
#  'that in black ink my love may still shine bright',
#  'tired with all these for restful death i cry',
#  'as to behold desert a beggar born',
#  'and needy nothing trimmd in jollity',
#  'and purest faith unhappily forsworn',
#  'and gilded honour shamefully misplacd',
#  'and maiden virtue rudely strumpeted',
#  'and right perfection wrongfully disgracd',
#  'and strength by limping sway disabled',
#  'and art made tonguetied by authority',
#  'and follydoctorlikecontrolling skill',
#  'and simple truth miscalld simplicity',
#  'and captive good attending captain ill',
#  'tird with all these from these would i be gone',
#  'save that to die i leave my love alone',
#  'ah wherefore with infection should he live',
#  'and with his presence grace impiety',
#  'that sin by him advantage should achieve',
#  'and lace itself with his society',
#  'why should false painting imitate his cheek',
#  'and steel dead seeming of his living hue',
#  'why should poor beauty indirectly seek',
#  'roses of shadow since his rose is true',
#  'why should he live now nature bankrupt is',
#  'beggard of blood to blush through lively veins',
#  'for she hath no exchequer now but his',
#  'and proud of many lives upon his gains',
#  'o him she stores to show what wealth she had',
#  'in days long since before these last so bad',
#  'thus is his cheek the map of days outworn',
#  'when beauty lived and died as flowers do now',
#  'before these bastard signs of fair were born',
#  'or durst inhabit on a living brow',
#  'before the golden tresses of the dead',
#  'the right of sepulchres were shorn away',
#  'to live a second life on second head',
#  'ere beautys dead fleece made another gay',
#  'in him those holy antique hours are seen',
#  'without all ornament itself and true',
#  'making no summer of anothers green',
#  'robbing no old to dress his beauty new',
#  'and him as for a map doth nature store',
#  'to show false art what beauty was of yore',
#  'those parts of thee that the worlds eye doth view',
#  'want nothing that the thought of hearts can mend',
#  'all tonguesthe voice of soulsgive thee that due',
#  'uttering bare truth even so as foes commend',
#  'thy outward thus with outward praise is crownd',
#  'but those same tongues that give thee so thine own',
#  'in other accents do this praise confound',
#  'by seeing farther than the eye hath shown',
#  'they look into the beauty of thy mind',
#  'and that in guess they measure by thy deeds',
#  'thenchurlstheir thoughts although their eyes were kind',
#  'to thy fair flower add the rank smell of weeds',
#  'but why thy odour matcheth not thy show',
#  'the soil is this that thou dost common grow',
#  'that thou art blamd shall not be thy defect',
#  'for slanders mark was ever yet the fair',
#  'the ornament of beauty is suspect',
#  'a crow that flies in heavens sweetest air',
#  'so thou be good slander doth but approve',
#  'thy worth the greater being wood of time',
#  'for canker vice the sweetest buds doth love',
#  'and thou presentst a pure unstained prime',
#  'thou hast passed by the ambush of young days',
#  'either not assaild or victor being chargd',
#  'yet this thy praise cannot be so thy praise',
#  'to tie up envy evermore enlargd',
#  'if some suspect of ill maskd not thy show',
#  'then thou alone kingdoms of hearts shouldst owe',
#  'no longer mourn for me when i am dead',
#  'than you shall hear the surly sullen bell',
#  'give warning to the world that i am fled',
#  'from this vile world with vilest worms to dwell',
#  'nay if you read this line remember not',
#  'the hand that writ it for i love you so',
#  'that i in your sweet thoughts would be forgot',
#  'if thinking on me then should make you woe',
#  'o ifi say you look upon this verse',
#  'when i perhaps compounded am with clay',
#  'do not so much as my poor name rehearse',
#  'but let your love even with my life decay',
#  'lest the wise world should look into your moan',
#  'and mock you with me after i am gone',
#  'o lest the world should task you to recite',
#  'what merit lived in me that you should love',
#  'after my deathdear love forget me quite',
#  'for you in me can nothing worthy prove',
#  'unless you would devise some virtuous lie',
#  'to do more for me than mine own desert',
#  ...]

# %%
def key(x):
  return len(x)

lensort = clean_sonnets.copy()
lensort.sort(key=key)

# %%
lensort
# Out:
# ['if any be a satire to decay',
#  'is poorly imitated after you',
#  'o no it is an everfixed mark',
#  'was usd in giving gentle doom',
#  'i hate she alterd with an end',
#  'without accusing you of injury',
#  'o what a happy title do i find',
#  'nor my beloved as an idol show',
#  'that followed it as gentle day',
#  'that use is not forbidden usury',
#  'to tie up envy evermore enlargd',
#  'i hate from hate away she threw',
#  'and savd my life saying not you',
#  'upon thy self thy beautys legacy',
#  'leaving thee living in posterity',
#  'the living record of your memory',
#  'self so selfloving were iniquity',
#  'for such a time do i now fortify',
#  'o fearful meditation where alack',
#  'and lace itself with his society',
#  'now proud as an enjoyer and anon',
#  'or gluttoning on all or all away',
#  'and heavy ignorance aloft to fly',
#  'and given grace a double majesty',
#  'the injuries that to myself i do',
#  'o benefit of ill now i find true',
#  'so i return rebukd to my content',
#  'at my abuses reckon up their own',
#  'beyond all date even to eternity',
#  'it fears not policy that heretic',
#  'or laid great bases for eternity',
#  'i grant i never saw a goddess go',
#  'but when she saw my woeful state',
#  'and taught it thus anew to greet',
#  'and so the general of hot desire',
#  'of his selflove to stop posterity',
#  'and yet methinks i have astronomy',
#  'and many maiden gardens yet unset',
#  'thy adverse party is thy advocate',
#  'that i an accessary needs must be',
#  'even for this let us divided live',
#  'in tender embassy of love to thee',
#  'until lifes composition be recurd',
#  'to side this title is impannelled',
#  'how heavy do i journey on the way',
#  'or captain jewels in the carcanet',
#  'even in the eyes of all posterity',
#  'or whether revolution be the same',
#  'as to behold desert a beggar born',
#  'or durst inhabit on a living brow',
#  'the ornament of beauty is suspect',
#  'too base of thee to be remembered',
#  'possessing or pursuing no delight',
#  'my saucy bark inferior far to his',
#  'to set a form upon desired change',
#  'to linger out a purposd overthrow',
#  'the lily i condemned for thy hand',
#  'let not my love be calld idolatry',
#  'creating every bad a perfect best',
#  'alas why fearing of times tyranny',
#  'i never writ nor no man ever lovd',
#  'as to prevent our maladies unseen',
#  'thus policy in love to anticipate',
#  'have faculty by nature to subsist',
#  'and her quietus is to render thee',
#  'the manner of my pitywanting pain',
#  'thy pity may deserve to pitied be',
#  'to me that languishd for her sake',
#  'from heaven to hell is flown away',
#  'for thou betraying me i do betray',
#  'which used lives th executor to be',
#  'attending on his golden pilgrimage',
#  'is it for fear to wet a widows eye',
#  'as an unperfect actor on the stage',
#  'the perfect ceremony of loves rite',
#  'to witness duty not to show my wit',
#  'save that my souls imaginary sight',
#  'their images i lovd i view in thee',
#  'as a decrepit father takes delight',
#  'or any of these all or all or more',
#  'that i in thy abundance am sufficd',
#  'for every vulgar paper to rehearse',
#  'that by this separation i may give',
#  'and by their verdict is determined',
#  'tomorrow see again and do not kill',
#  'o let me suffer being at your beck',
#  'nativity once in the main of light',
#  'making no summer of anothers green',
#  'o ifi say you look upon this verse',
#  'my name be buried where my body is',
#  'as after sunset fadeth in the west',
#  'and keep invention in a noted weed',
#  'as every alien pen hath got my use',
#  'that barren tender of a poets debt',
#  'for i impair not beauty being mute',
#  'in polishd form of wellrefined pen',
#  'giving him aid my verse astonished',
#  'he nor that affable familiar ghost',
#  'and i by this will be a gainer too',
#  'i see a better state to me belongs',
#  'and to be praisd of ages yet to be',
#  'ah yet doth beauty like a dialhand',
#  'a god in love to whom i am confind',
#  'incapable of more replete with you',
#  'when i was certain oer incertainty',
#  'admit impediments love is not love',
#  'if this be error and upon me provd',
#  'were to import forgetfulness in me',
#  'thy registers and thee i both defy',
#  'but mutual render only me for thee',
#  'ist not enough to torture me alone',
#  'among a number one is reckond none',
#  'o call not me to justify the wrong',
#  'i guess one angel in anothers hell',
#  'doth follow night who like a fiend',
#  'my reason the physician to my love',
#  'what merit do i in my self respect',
#  'more worthy i to be belovd of thee',
#  'and only herald to the gaudy spring',
#  'profitless usurer why dost thou use',
#  'who for thy self art so unprovident',
#  'when i behold the violet past prime',
#  'find no determination then you were',
#  'and fortify your self in your decay',
#  'and by addition me of thee defeated',
#  'but as the marigold at the suns eye',
#  'intend a zealous pilgrimage to thee',
#  'i all alone beweep my outcast state',
#  'how many a holy and obsequious tear',
#  'that due of many now is thine alone',
#  'myself corrupting salving thy amiss',
#  'i may not evermore acknowledge thee',
#  'and by a part of all thy glory live',
#  'are both with thee wherever i abide',
#  'so either by thy picture or my love',
#  'that to my use it might unused stay',
#  'till i return of posting is no need',
#  'describe adonis and the counterfeit',
#  'not marble nor the gilded monuments',
#  'nor services to do till you require',
#  'o sure i am the wits of former days',
#  'my heavy eyelids to the weary night',
#  'and for this sin there is no remedy',
#  'that he shall never cut from memory',
#  'or state itself confounded to decay',
#  'and needy nothing trimmd in jollity',
#  'and purest faith unhappily forsworn',
#  'and maiden virtue rudely strumpeted',
#  'and with his presence grace impiety',
#  'for as the sun is daily new and old',
#  'times thievish progress to eternity',
#  'look what thy memory cannot contain',
#  'and under thee their poesy disperse',
#  'doing thee vantage doublevantage me',
#  'such is my love to thee i so belong',
#  'and do not drop in for an afterloss',
#  'happy to have thy love happy to die',
#  'unmoved cold and to temptation slow',
#  'as on the finger of a throned queen',
#  'yet this abundant issue seemd to me',
#  'nor did i wonder at the lilys white',
#  'the forward violet thus did i chide',
#  'but best is best if never intermixd',
#  'for to no other pass my verses tend',
#  'kind is my love today tomorrow kind',
#  'as easy might i from my self depart',
#  'made old offences of affections new',
#  'pity me then and wish i were renewd',
#  'none else to me nor i to none alive',
#  'seems seeing but effectually is out',
#  'if it be poisond tis the lesser sin',
#  'or bends with the remover to remove',
#  'full characterd with lasting memory',
#  'to keep an adjunct to remember thee',
#  'no it was builded far from accident',
#  'but all alone stands hugely politic',
#  'weret aught to me i bore the canopy',
#  'mad in pursuit and in possession so',
#  'before a joy proposd behind a dream',
#  'although i swear it to myself alone',
#  'by selfexample mayst thou be denied',
#  'suspect i may yet not directly tell',
#  'chiding that tongue that ever sweet',
#  'my love is as a fever longing still',
#  'and franticmad with evermore unrest',
#  'with insufficiency my heart to sway',
#  'growing a bath and healthful remedy',
#  'making a famine where abundance lies',
#  'but if thou live rememberd not to be',
#  'so thou thyself outgoing in thy noon',
#  'you had a father let your son say so',
#  'but not to tell of good or evil luck',
#  'by oft predict that i in heaven find',
#  'or else of thee this i prognosticate',
#  'him in thy course untainted do allow',
#  'making a couplement of proud compare',
#  'so i for fear of trust forget to say',
#  'o let my looks be then the eloquence',
#  'then happy i that love and am belovd',
#  'where i may not remove nor be removd',
#  'lord of my love to whom in vassalage',
#  'thy merit hath my duty strongly knit',
#  'weary with toil i haste me to my bed',
#  'but then begins a journey in my head',
#  'that am debarred the benefit of rest',
#  'and heavily from woe to woe tell oer',
#  'the sad account of forebemoaned moan',
#  'if thou survive my wellcontented day',
#  'to march in ranks of better equipage',
#  'with ugly rack on his celestial face',
#  'although our undivided loves are one',
#  'entitled in thy parts do crowned sit',
#  'eternal numbers to outlive long date',
#  'by looking on thee in the living day',
#  'receiving nought by elements so slow',
#  'how careful was i when i took my way',
#  'by new unfolding his imprisond pride',
#  'the other as your bounty doth appear',
#  'gainst death and alloblivious enmity',
#  'which but today by feeding is allayd',
#  'the second burthen of a former child',
#  'whr we are mended or whr better they',
#  'the scope and tenure of thy jealousy',
#  'it is so grounded inward in my heart',
#  'against my love shall be as i am now',
#  'against confounding ages cruel knife',
#  'ruin hath taught me thus to ruminate',
#  'and art made tonguetied by authority',
#  'and follydoctorlikecontrolling skill',
#  'and simple truth miscalld simplicity',
#  'to live a second life on second head',
#  'without all ornament itself and true',
#  'and mock you with me after i am gone',
#  'and hang more praise upon deceased i',
#  'without all bail shall carry me away',
#  'the very part was consecrate to thee',
#  'the prey of worms my body being dead',
#  'spending again what is already spent',
#  'whilst i alone did call upon thy aid',
#  'o how i faint when i of you do write',
#  'then if he thrive and i be cast away',
#  'or i shall live your epitaph to make',
#  'let him but copy what in you is writ',
#  'making his style admired every where',
#  'my bonds in thee are all determinate',
#  'upon thy part i can set down a story',
#  'and i will comment upon that offence',
#  'could make me any summers story tell',
#  'in gentle numbers time so idly spent',
#  'to one of one still such and ever so',
#  'when in the chronicle of wasted time',
#  'and beauty making beautiful old rime',
#  'even such a beauty as you master now',
#  'of this our time all you prefiguring',
#  'but makes antiquity for aye his page',
#  'like him that travels i return again',
#  'so you oergreen my bad my good allow',
#  'for it no form delivers to the heart',
#  'and on just proof surmise accumulate',
#  'and ruind love when it is built anew',
#  'and i a tyrant have no leisure taken',
#  'give salutation to my sportive blood',
#  'this i do vow and this shall ever be',
#  'with my extern the outward honouring',
#  'no let me be obsequious in thy heart',
#  'past reason hunted and no sooner had',
#  'past reason hated as a swallowd bait',
#  'as any she belied with false compare',
#  'thou art as tyrannous so as thou art',
#  'one on anothers neck do witness bear',
#  'and suit thy pity like in every part',
#  'of him myself and thee i am forsaken',
#  'for thou art covetous and he is kind',
#  'and in abundance addeth to his store',
#  'if eyes corrupt by overpartial looks',
#  'that i may not be so nor thou belied',
#  'to any sensual feast with thee alone',
#  'the better angel is a man right fair',
#  'straight in her heart did mercy come',
#  'do i not think on thee when i forgot',
#  'that in the very refuse of thy deeds',
#  'o though i love what others do abhor',
#  'if thy unworthiness raisd love in me',
#  'a maid of dians this advantage found',
#  'the little lovegod lying once asleep',
#  'the fairest votary took up that fire',
#  'his tender heir might bear his memory',
#  'disdains the tillage of thy husbandry',
#  'or who is he so fond will be the tomb',
#  'for neverresting time leads summer on',
#  'nor it nor no remembrance what it was',
#  'doth homage to his newappearing sight',
#  'serving with looks his sacred majesty',
#  'by unions married do offend thine ear',
#  'ah if thou issueless shalt hap to die',
#  'make thee another self for love of me',
#  'without this folly age and cold decay',
#  'then of thy beauty do i question make',
#  'make war upon this bloody tyrant time',
#  'shall i compare thee to a summers day',
#  'but thy eternal summer shall not fade',
#  'for beautys pattern to succeeding men',
#  'o let me true in love but truly write',
#  'is but the seemly raiment of my heart',
#  'how can i then be elder than thou art',
#  'as i not for myself but for thee will',
#  'thy beautys form in table of my heart',
#  'my body is the frame wherein tis held',
#  'unlookd for joy in that i honour most',
#  'after a thousand victories once foild',
#  'to thee i send this written embassage',
#  'and puts apparel on my tatterd loving',
#  'for thee and for myself no quiet find',
#  'how can i then return in happy plight',
#  'the one by toil the other to complain',
#  'which i new pay as if not paid before',
#  'thy bosom is endeared with all hearts',
#  'which i by lacking have supposed dead',
#  'exceeded by the height of happier men',
#  'anon permit the basest clouds to ride',
#  'authorizing thy trespass with compare',
#  'such civil war is in my love and hate',
#  'without thy help by me be borne alone',
#  'though in our lives a separable spite',
#  'i do forgive thy robbery gentle thief',
#  'and when a woman woos what womans son',
#  'thine by thy beauty being false to me',
#  'but heavy tears badges of eithers woe',
#  'but the defendant doth that plea deny',
#  'thee have i not lockd up in any chest',
#  'shall reasons find of settled gravity',
#  'when what i seek my weary travels end',
#  'the bloody spur cannot provoke him on',
#  'which heavily he answers with a groan',
#  'so am i as the rich whose blessed key',
#  'and you but one can every shadow lend',
#  'on helens cheek all art of beauty set',
#  'as the perfumed tincture of the roses',
#  'they live unwood and unrespected fade',
#  'the imprisond absence of your liberty',
#  'yourself to pardon of selfdoing crime',
#  'to this composed wonder of your frame',
#  'so do our minutes hasten to their end',
#  'so far from home into my deeds to pry',
#  'and all my soul and all my every part',
#  'as i all other in all worths surmount',
#  'hath travelld on to ages steepy night',
#  'advantage on the kingdom of the shore',
#  'or who his spoil of beauty can forbid',
#  'o none unless this miracle have might',
#  'and gilded honour shamefully misplacd',
#  'and strength by limping sway disabled',
#  'for she hath no exchequer now but his',
#  'before the golden tresses of the dead',
#  'they look into the beauty of thy mind',
#  'no longer mourn for me when i am dead',
#  'thus do i pine and surfeit day by day',
#  'so far from variation or quick change',
#  'as high as learning my rude ignorance',
#  'yet what of thee thy poet doth invent',
#  'or being wrackd i am a worthless boat',
#  'the dedicated words which writers use',
#  'thou truly fair wert truly sympathizd',
#  'in whose confine immured is the store',
#  'as victors of my silence cannot boast',
#  'against thy reasons making no defence',
#  'give not a windy night a rainy morrow',
#  'wherein it finds a joy above the rest',
#  'like a deceived husband so loves face',
#  'but heaven in thy creation did decree',
#  'though to itself it only live and die',
#  'the basest weed outbraves his dignity',
#  'naming thy name blesses an ill report',
#  'o what a mansion have those vices got',
#  'the basest jewel will be well esteemd',
#  'and thou away the very birds are mute',
#  'a vengeful canker eat him up to death',
#  'if time have any wrinkle graven there',
#  'beauty no pencil beautys truth to lay',
#  'o blame me not if i no more can write',
#  'in process of the seasons have i seen',
#  'fair kind and true is all my argument',
#  'of hand of foot of lip of eye of brow',
#  'supposed as forfeit to a confind doom',
#  'i must each day say oer the very same',
#  'weighs not the dust and injury of age',
#  'nor gives to necessary wrinkles place',
#  'o never say that i was false of heart',
#  'for nothing this wide universe i call',
#  'and made my self a motley to the view',
#  'mine appetite i never more will grind',
#  'on newer proof to try an older friend',
#  'and almost thence my nature is subdud',
#  'in so profound abysm i throw all care',
#  'of others voices that my adders sense',
#  'and that which governs me to go about',
#  'which alters when it alteration finds',
#  'forgot upon your dearest love to call',
#  'the constancy and virtue of your love',
#  'still losing when i saw myself to win',
#  'no i am that i am and they that level',
#  'of thee thy record never can be missd',
#  'under the blow of thralled discontent',
#  'o thou my lovely boy who in thy power',
#  'to kiss the tender inward of thy hand',
#  'on purpose laid to make the taker mad',
#  'a bliss in proof and provd a very woe',
#  'but no such roses see i in her cheeks',
#  'to say they err i dare not be so bold',
#  'looking with pretty ruth upon my pain',
#  'and i my self am mortgagd to thy will',
#  'myself ill forfeit so that other mine',
#  'so him i lose through my unkind abuse',
#  'and will to boot and will in overplus',
#  'let no unkind no fair beseechers kill',
#  'then in the number let me pass untold',
#  'to put fair truth upon so foul a face',
#  'and wherefore say not i that i am old',
#  'the worser spirit a woman colourd ill',
#  'to win me soon to hell my female evil',
#  'tempteth my better angel from my side',
#  'wooing his purity with her foul pride',
#  'shall worms inheritors of this excess',
#  'within be fed without be rich no more',
#  'am of my self all tyrant for thy sake',
#  'revenge upon myself with present moan',
#  'commanded by the motion of thine eyes',
#  'then gentle cheater urge not my amiss',
#  'my soul doth tell my body that he may',
#  'he is contented thy poor drudge to be',
#  'when i break twenty i am perjurd most',
#  'was sleeping by a virgin hand disarmd',
#  'pity the world or else this glutton be',
#  'proving his beauty by succession thine',
#  'for having traffic with thy self alone',
#  'what acceptable audit canst thou leave',
#  'will play the tyrants to the very same',
#  'beautys effect with beauty were bereft',
#  'or ten times happier be it ten for one',
#  'unlookd on diest unless thou get a son',
#  'when every private widow well may keep',
#  'seeking that beauteous roof to ruinate',
#  'yourself again after yourselfs decease',
#  'who lets so fair a house fall to decay',
#  'which husbandry in honour might uphold',
#  'and barren rage of deaths eternal cold',
#  'when i consider every thing that grows',
#  'as he takes from you i engraft you new',
#  'and stretched metre of an antique song',
#  'and often is his gold complexion dimmd',
#  'gilding the object whereupon it gazeth',
#  'so is it not with me as with that muse',
#  'and then believe me my love is as fair',
#  'o therefore love be of thyself so wary',
#  'for at a frown they in their glory die',
#  'the painful warrior famoused for fight',
#  'is from the book of honour razed quite',
#  'to show me worthy of thy sweet respect',
#  'and keep my drooping eyelids open wide',
#  'and look upon myself and curse my fate',
#  'with what i most enjoy contented least',
#  'i summon up remembrance of things past',
#  'then can i drown an eye unused to flow',
#  'all losses are restord and sorrows end',
#  'and thouall theyhast all the all of me',
#  'but out alack he was but one hour mine',
#  'to dry the rain on my stormbeaten face',
#  'all men make faults and even i in this',
#  'but do not so i love thee in such sort',
#  'i make my love engrafted to this store',
#  'so then i am not lame poor nor despisd',
#  'how can my muse want subject to invent',
#  'thine own sweet argument too excellent',
#  'worthy perusal stand against thy sight',
#  'who lead thee in their riot even there',
#  'loving offenders thus i will excuse ye',
#  'of thy fair health recounting it to me',
#  'mine eye and heart are at a mortal war',
#  'but thou to whom my jewels trifles are',
#  'within the gentle closure of my breast',
#  'calld to that audit by advisd respects',
#  'my grief lies onward and my joy behind',
#  'when swift extremity can seem but slow',
#  'in winged speed no motion shall i know',
#  'and you in every blessed shape we know',
#  'tomorrow sharpened in his former might',
#  'let this sad interim like the ocean be',
#  'to what you will to you it doth belong',
#  'i am to wait though waiting so be hell',
#  'feeds on the rarities of natures truth',
#  'to play the watchman ever for thy sake',
#  'tis theemyselfthat for myself i praise',
#  'are vanishing or vanished out of sight',
#  'and brass eternal slave to mortal rage',
#  'when i have seen the hungry ocean gain',
#  'but sad mortality oersways their power',
#  'and captive good attending captain ill',
#  'save that to die i leave my love alone',
#  'why should poor beauty indirectly seek',
#  'roses of shadow since his rose is true',
#  'and proud of many lives upon his gains',
#  'robbing no old to dress his beauty new',
#  'and him as for a map doth nature store',
#  'nay if you read this line remember not',
#  'when i perhaps compounded am with clay',
#  'for you in me can nothing worthy prove',
#  'to do more for me than mine own desert',
#  'as the deathbed whereon it must expire',
#  'but be contented when that fell arrest',
#  'the coward conquest of a wretchs knife',
#  'now counting best to be with you alone',
#  'and by and by clean starved for a look',
#  'why is my verse so barren of new pride',
#  'and you and love are still my argument',
#  'to take a new acquaintance of thy mind',
#  'these offices so oft as thou wilt look',
#  'so oft have i invoked thee for my muse',
#  'but now my gracious numbers are decayd',
#  'i grant sweet love thy lovely argument',
#  'deserves the travail of a worthier pen',
#  'he robs thee of and pays it thee again',
#  'from thy behaviour beauty doth he give',
#  'the worst was thismy love was my decay',
#  'your monument shall be my gentle verse',
#  'i never saw that you did painting need',
#  'this silence for my sin you did impute',
#  'lean penury within that pen doth dwell',
#  'to every hymn that able spirit affords',
#  'i was not sick of any fear from thence',
#  'and place my merit in the eye of scorn',
#  'upon thy side against myself ill fight',
#  'and haply of our old acquaintance tell',
#  'come in the rearward of a conquerd woe',
#  'but in the onset come so shall i taste',
#  'all these i better in one general best',
#  'but do thy worst to steal thyself away',
#  'for term of life thou art assured mine',
#  'for it depends upon that love of thine',
#  'they rightly do inherit heavens graces',
#  'how many gazers mightst thou lead away',
#  'but do not so i love thee in such sort',
#  'how like a winter hath my absence been',
#  'what old decembers bareness everywhere',
#  'bearing the wanton burden of the prime',
#  'yet seemd it winter still and you away',
#  'o truant muse what shall be thy amends',
#  'for thy neglect of truth in beauty dyd',
#  'so dost thou too and therein dignified',
#  'to make him much outlive a gilded tomb',
#  'as philomel in summers front doth sing',
#  'the argument all bare is of more worth',
#  'that overgoes my blunt invention quite',
#  'dulling my lines and doing me disgrace',
#  'to me fair friend you never can be old',
#  'askance and strangely but by all above',
#  'the guilty goddess of my harmful deeds',
#  'no bitterness that i will bitter think',
#  'to critic and to flatterer stopped are',
#  'mark how with my neglect i do dispense',
#  'you are so strongly in my purpose bred',
#  'and to his palate doth prepare the cup',
#  'love is a babe then might i not say so',
#  'it is the star to every wandering bark',
#  'accuse me thus that i have scanted all',
#  'whereto all bonds do tie me day by day',
#  'like as to make our appetite more keen',
#  'unless this general evil they maintain',
#  'thy pyramids built up with newer might',
#  'pitiful thrivers in their gazing spent',
#  'or if it were it bore not beautys name',
#  'slandring creation with a false esteem',
#  'do i envy those jacks that nimble leap',
#  'and situation with those dancing chips',
#  'since saucy jacks so happy are in this',
#  'is lust in action and till action lust',
#  'savage extreme rude cruel not to trust',
#  'enjoyd no sooner but despised straight',
#  'doth half that glory to the sober west',
#  'o let it then as well beseem thy heart',
#  'to thy sweet will making addition thus',
#  'o loves best habit is in seeming trust',
#  'that thy unkindness lays upon my heart',
#  'be wise as thou art cruel do not press',
#  'mad slanderers by mad ears believed be',
#  'till my bad angel fire my good one out',
#  'past cure i am now reason is past care',
#  'how can it o how can loves eye be true',
#  'canst thou o cruel say i love thee not',
#  'a dateless lively heat still to endure',
#  'i sick withal the help of bath desired',
#  'but as the riper should by time decease',
#  'thy youths proud livery so gazed on now',
#  'and that unfair which fairly doth excel',
#  'then were not summers distillation left',
#  'then let not winters ragged hand deface',
#  'in thee thy summer ere thou be distilld',
#  'if ten of thine ten times refigurd thee',
#  'yet mortal looks adore his beauty still',
#  'like feeble age he reeleth from the day',
#  'the eyes fore duteous now converted are',
#  'from his low tract and look another way',
#  'if the true concord of welltuned sounds',
#  'strikes each in each by mutual ordering',
#  'and kept unused the user so destroys it',
#  'be as thy presence is gracious and kind',
#  'herein lives wisdom beauty and increase',
#  'when lofty trees i see barren of leaves',
#  'and die as fast as they see others grow',
#  'against the stormy gusts of winters day',
#  'nor can i fortune to brief minutes tell',
#  'or say with princes if it shall go well',
#  'holds in perfection but a little moment',
#  'where wasteful time debateth with decay',
#  'but wherefore do not you a mightier way',
#  'now stand you on the top of happy hours',
#  'which this times pencil or my pupil pen',
#  'thou art more lovely and more temperate',
#  'and for a woman wert thou first created',
#  'stirrd by a painted beauty to his verse',
#  'who heaven itself for ornament doth use',
#  'my glass shall not persuade me i am old',
#  'but when in thee times furrows i behold',
#  'and perspective it is best painters art',
#  'of public honour and proud titles boast',
#  'duty so great which wit so poor as mine',
#  'do in consent shake hands to torture me',
#  'so flatter i the swartcomplexiond night',
#  'haply i think on thee and then my state',
#  'and shalt by fortune once more resurvey',
#  'even so my sun one early morn did shine',
#  'to let base clouds oertake me in my way',
#  'nor thou with public kindness honour me',
#  'o how thy worth with manners may i sing',
#  'when thou art all the better part of me',
#  'although thou steal thee all my poverty',
#  'gentle thou art and therefore to be won',
#  'hers by thy beauty tempting her to thee',
#  'if i lose thee my loss is my loves gain',
#  'who even but now come back again assurd',
#  'this told i joy but then no longer glad',
#  'how to divide the conquest of thy sight',
#  'a closet never piercd with crystal eyes',
#  'thy self away art present still with me',
#  'each trifle under truest bars to thrust',
#  'thou best of dearest and mine only care',
#  'art left the prey of every vulgar thief',
#  'against that time do i ensconce me here',
#  'within the knowledge of mine own desert',
#  'and this my hand against my self uprear',
#  'to guard the lawful reasons on thy part',
#  'since why to love i can allege no cause',
#  'the which he will not every hour survey',
#  'the one doth shadow of your beauty show',
#  'but for their virtue only is their show',
#  'die to themselves sweet roses do not so',
#  'and broils root out the work of masonry',
#  'upon the hours and times of your desire',
#  'i have no precious time at all to spend',
#  'though you do anything he thinks no ill',
#  'even of five hundred courses of the sun',
#  'show me your image in some antique book',
#  'in sequent toil all forwards do contend',
#  'crooked eclipses gainst his glory fight',
#  'to find out shames and idle hours in me',
#  'it is my love that keeps mine eye awake',
#  'sin of selflove possesseth all mine eye',
#  'methinks no face so gracious is as mine',
#  'and for myself mine own worth do define',
#  'beated and choppd with tanned antiquity',
#  'mine own selflove quite contrary i read',
#  'painting my age with beauty of thy days',
#  'when rocks impregnable are not so stout',
#  'the right of sepulchres were shorn away',
#  'but why thy odour matcheth not thy show',
#  'for slanders mark was ever yet the fair',
#  'the hand that writ it for i love you so',
#  'do not so much as my poor name rehearse',
#  'after my deathdear love forget me quite',
#  'that on the ashes of his youth doth lie',
#  'my life hath in this line some interest',
#  'why with the time do i not glance aside',
#  'why write i still all one ever the same',
#  'o know sweet love i always write of you',
#  'thy dial how thy precious minutes waste',
#  'of mouthed graves will give thee memory',
#  'my verse alone had all thy gentle grace',
#  'and found it in thy cheek he can afford',
#  'on your broad main doth wilfully appear',
#  'he of tall building and of goodly pride',
#  'thou art as fair in knowledge as in hue',
#  'and therefore art enforced to seek anew',
#  'what strained touches rhetoric can lend',
#  'which shall be most my glory being dumb',
#  'that you are you so dignifies his story',
#  'no neither he nor his compeers by night',
#  'and so my patent back again is swerving',
#  'as ill myself disgrace knowing thy will',
#  'for thee against my self ill vow debate',
#  'then hate me when thou wilt if ever now',
#  'all this away and me most wretchcd make',
#  'so shall i live supposing thou art true',
#  'in manys looks the false hearts history',
#  'if thy sweet virtue answer not thy show',
#  'and husband natures riches from expense',
#  'others but stewards of their excellence',
#  'making lascivious comments on thy sport',
#  'but hope of orphans and unfatherd fruit',
#  'and buds of marjoram had stoln thy hair',
#  'the roses fearfully on thorns did stand',
#  'excuse not silence so fort lies in thee',
#  'alack what poverty my muse brings forth',
#  'to mar the subject that before was well',
#  'hath motion and mine eye may be deceivd',
#  'since all alike my songs and praises be',
#  'still constant in a wondrous excellence',
#  'therefore my verse to constancy confind',
#  'so all their praises are but prophecies',
#  'the mortal moon hath her eclipse endurd',
#  'whats new to speak what now to register',
#  'that is my home of love if i have rangd',
#  'so that myself bring water for my stain',
#  'save thou my rose in it thou art my all',
#  'o for my sake do you with fortune chide',
#  'that did not better for my life provide',
#  'to what it works in like the dyers hand',
#  'since i left you mine eye is in my mind',
#  'to make of monsters and things indigest',
#  'yet then my judgment knew no reason why',
#  'within his bending sickles compass come',
#  'book both my wilfulness and errors down',
#  'bring me within the level of your frown',
#  'but shoot not at me in your wakend hate',
#  'with eager compounds we our palate urge',
#  'to bitter sauces did i frame my feeding',
#  'needs must i under my transgression bow',
#  'for if you were by my unkindness shaken',
#  'tis better to be vile than vile esteemd',
#  'not by our feeling but by others seeing',
#  'thy gift thy tables are within my brain',
#  'which shall above that idle rank remain',
#  'to me are nothing novel nothing strange',
#  'and rather make them born to our desire',
#  'and take thou my oblation poor but free',
#  'if nature sovereign mistress over wrack',
#  'sweet beauty hath no name no holy bower',
#  'but is profand if not lives in disgrace',
#  'yet so they mourn becoming of their woe',
#  'how oft when thou my music music playst',
#  'had having and in quest to have extreme',
#  'coral is far more red than her lips red',
#  'i have seen roses damaskd red and white',
#  'and truly not the morning sun of heaven',
#  'me from myself thy cruel eye hath taken',
#  'perforce am thine and all that is in me',
#  'so now i have confessd that he is thine',
#  'he pays the whole and yet am i not free',
#  'and in my will no fair acceptance shine',
#  'i do believe her though i know she lies',
#  'her pretty looks have been mine enemies',
#  'yet do not so but since i am near slain',
#  'for they in thee a thousand errors note',
#  'but my five wits nor my five senses can',
#  'only my plague thus far i count my gain',
#  'love is my sin and thy dear virtue hate',
#  'lo as a careful housewife runs to catch',
#  'not prizing her poor infants discontent',
#  'two loves i have of comfort and despair',
#  'those lips that loves own hand did make',
#  'poor soul the centre of my sinful earth',
#  'dost thou upon thy fading mansion spend',
#  'eat up thy charge is this thy bodys end',
#  'the uncertain sickly appetite to please',
#  'desire is death which physic did except',
#  'o me what eyes hath love put in my head',
#  'if it be not then love doth well denote',
#  'loves eye is not so true as all mens no',
#  'no marvel then though i mistake my view',
#  'when i against myself with thee partake',
#  'nay if thou lourst on me do i not spend',
#  'that is so proud thy service to despise',
#  'and all my honest faith in thee is lost',
#  'cupid laid by his brand and fell asleep',
#  'in a cold valleyfountain of that ground',
#  'and thither hied a sad distemperd guest',
#  'came tripping by but in her maiden hand',
#  'within thine own bud buriest thy content',
#  'where all the treasure of thy lusty days',
#  'to say within thine own deep sunken eyes',
#  'calls back the lovely april of her prime',
#  'despite of wrinkles this thy golden time',
#  'unthrifty loveliness why dost thou spend',
#  'the bounteous largess given thee to give',
#  'a liquid prisoner pent in walls of glass',
#  'thats for thy self to breed another thee',
#  'lo in the orient when the gracious light',
#  'lifts up his burning head each under eye',
#  'who all in one one pleasing note do sing',
#  'no love toward others in that bosom sits',
#  'but that thou none lovst is most evident',
#  'or to thyself at least kindhearted prove',
#  'which erst from heat did canopy the herd',
#  'of plagues of dearths or seasons quality',
#  'and wear their brave state out of memory',
#  'then the conceit of this inconstant stay',
#  'and all in war with time for love of you',
#  'much liker than your painted counterfeit',
#  'neither in inward worth nor outward fair',
#  'if i could write the beauty of your eyes',
#  'the age to come would say this poet lies',
#  'devouring time blunt thou the lions paws',
#  'but i forbid thee one most heinous crime',
#  'a womans gentle heart but not acquainted',
#  'a man in hue all hues in his controlling',
#  'then look i death my days should expiate',
#  'for all that beauty that doth cover thee',
#  'as tender nurse her babe from faring ill',
#  'who with his fear is put beside his part',
#  'and dumb presagers of my speaking breast',
#  'which in my bosoms shop is hanging still',
#  'delights to peep to gaze therein on thee',
#  'points on me graciously with fair aspect',
#  'to work my mind when bodys works expired',
#  'presents thy shadow to my sightless view',
#  'which like a jewel hung in ghastly night',
#  'lo thus by day my limbs by night my mind',
#  'and each though enemies to eithers reign',
#  'wishing me like to one more rich in hope',
#  'like to the lark at break of day arising',
#  'i sigh the lack of many a thing i sought',
#  'then can i grieve at grievances foregone',
#  'as interest of the dead which now appear',
#  'hung with the trophies of my lovers gone',
#  'but since he died and poets better prove',
#  'full many a glorious morning have i seen',
#  'with all triumphant splendour on my brow',
#  'hiding thy bravery in their rotten smoke',
#  'excusing thy sins more than thy sins are',
#  'and gainst myself a lawful plea commence',
#  'let me confess that we two must be twain',
#  'so i made lame by fortunes dearest spite',
#  'this wish i have then ten times happy me',
#  'by wilful taste of what thyself refusest',
#  'and yet love knows it is a greater grief',
#  'those pretty wrongs that liberty commits',
#  'when i am sometime absent from thy heart',
#  'upon the farthest earth removd from thee',
#  'i must attend times leisure with my moan',
#  'the first my thought the other my desire',
#  'for when these quicker elements are gone',
#  'and says in him thy fair appearance lies',
#  'when that mine eye is famishd for a look',
#  'and to the painted banquet bids my heart',
#  'another time mine eye is my hearts guest',
#  'or if they sleep thy picture in my sight',
#  'against that time if ever that time come',
#  'plods dully on to bear that weight in me',
#  'thus can my love excuse the slow offence',
#  'of my dull bearer when from thee i speed',
#  'since from thee going he went wilfulslow',
#  'since every one hath every one one shade',
#  'and you in grecian tires are painted new',
#  'in all external grace you have some part',
#  'hang on such thorns and play as wantonly',
#  'and so of you beauteous and lovely youth',
#  'when wasteful war shall statues overturn',
#  'so till the judgment that yourself arise',
#  'thy edge should blunter be than appetite',
#  'so love be thou although today thou fill',
#  'nor think the bitterness of absence sour',
#  'where you may be or your affairs suppose',
#  'so true a fool is love that in your will',
#  'which labouring for invention bear amiss',
#  'o that record could with a backward look',
#  'and delves the parallels in beautys brow',
#  'from me far off with others all too near',
#  'but when my glass shows me myself indeed',
#  'stealing away the treasure of his spring',
#  'the richproud cost of outworn buried age',
#  'and the firm soil win of the watery main',
#  'and right perfection wrongfully disgracd',
#  'that sin by him advantage should achieve',
#  'and steel dead seeming of his living hue',
#  'ere beautys dead fleece made another gay',
#  'in him those holy antique hours are seen',
#  'in other accents do this praise confound',
#  'so thou be good slander doth but approve',
#  'thy worth the greater being wood of time',
#  'give warning to the world that i am fled',
#  'and live no more to shame nor me nor you',
#  'my spirit is thine the better part of me',
#  'as twixt a miser and his wealth is found',
#  'that every word doth almost tell my name',
#  'so all my best is dressing old words new',
#  'so is my love still telling what is told',
#  'have added feathers to the learneds wing',
#  'and arts with thy sweet graces graced be',
#  'but thou art all my art and dost advance',
#  'but since your worthwide as the ocean is',
#  'or you survive when i in earth am rotten',
#  'from hence your memory death cannot take',
#  'when you entombed in mens eyes shall lie',
#  'which eyes not yet created shall oerread',
#  'i grant thou wert not married to my muse',
#  'finding thy worth a limit past my praise',
#  'and do so love yet when they have devisd',
#  'but he that writes of you if he can tell',
#  'and like unlettered clerk still cry amen',
#  'above a mortal pitch that struck me dead',
#  'then lacked i matter that enfeebled mine',
#  'and like enough thou knowst thy estimate',
#  'but these particulars are not my measure',
#  'thy love is better than high birth to me',
#  'of more delight than hawks and horses be',
#  'how like eves apple doth thy beauty grow',
#  'which like a canker in the fragrant rose',
#  'doth spot the beauty of thy budding name',
#  'cannot dispraise but in a kind of praise',
#  'where beautys veil doth cover every blot',
#  'or if they sing tis with so dull a cheer',
#  'of different flowers in odour and in hue',
#  'drawn after you you pattern of all those',
#  'one blushing shame another white despair',
#  'and to his robbery had annexd thy breath',
#  'both truth and beauty on my love depends',
#  'make answer muse wilt thou not haply say',
#  'then do thy office muse i teach thee how',
#  'when i was wont to greet it with my lays',
#  'not that the summer is less pleasant now',
#  'but that wild music burthens every bough',
#  'than when it hath my added praise beside',
#  'were it not sinful then striving to mend',
#  'and in this change is my invention spent',
#  'fair kind and true have often livd alone',
#  'i see descriptions of the fairest wights',
#  'then in the blazon of sweet beautys best',
#  'and thou in this shalt find thy monument',
#  'so that eternal love in loves fresh case',
#  'though absence seemd my flame to qualify',
#  'never believe though in my nature reignd',
#  'to leave for nothing all thy sum of good',
#  'alas tis true i have gone here and there',
#  'nor double penance to correct correction',
#  'pity me then dear friend and i assure ye',
#  'even that your pity is enough to cure me',
#  'which vulgar scandal stampd upon my brow',
#  'for what care i who calls me well or ill',
#  'you are my alltheworld and i must strive',
#  'the mountain or the sea the day or night',
#  'as fast as objects to his beams assemble',
#  'might i not then say now i love you best',
#  'let me not to the marriage of true minds',
#  'we sicken to shun sickness when we purge',
#  'what potions have i drunk of siren tears',
#  'in the distraction of this madding fever',
#  'that better is by evil still made better',
#  'as i by yours youve passd a hell of time',
#  'but that your trespass now becomes a fee',
#  'or on my frailties why are frailer spies',
#  'they are but dressings of a former sight',
#  'what thou dost foist upon us that is old',
#  'for thy records and what we see doth lie',
#  'made more or less by thy continual haste',
#  'it suffers not in smiling pomp nor falls',
#  'to this i witness call the fools of time',
#  'hence thou suborned informer a true soul',
#  'but now is black beautys successive heir',
#  'and beauty slanderd with a bastard shame',
#  'at such who not born fair no beauty lack',
#  'the wiry concord that mine ear confounds',
#  'i love to hear her speak yet well i know',
#  'and to be sure that is not false i swear',
#  'thine eyes i love and they as pitying me',
#  'have put on black and loving mourners be',
#  'prison my heart in thy steel bosoms ward',
#  'thou wilt restore to be my comfort still',
#  'he learnd but suretylike to write for me',
#  'the statute of thy beauty thou wilt take',
#  'thou usurer that puttst forth all to use',
#  'and sue a friend came debtor for my sake',
#  'whoever hath her wish thou hast thy will',
#  'shall will in others seem right gracious',
#  'be anchord in the bay where all men ride',
#  'whereto the judgment of my heart is tied',
#  'or mine eyes seeing this say this is not',
#  'unlearned in the worlds false subtleties',
#  'simply i credit her falsespeaking tongue',
#  'but wherefore says she not she is unjust',
#  'therefore i lie with her and she with me',
#  'and in our faults by lies we flatterd be',
#  'let me excuse thee ah my love well knows',
#  'if i might teach thee wit better it were',
#  'nor tender feeling to base touches prone',
#  'nor taste nor smell desire to be invited',
#  'who leaves unswayd the likeness of a man',
#  'hate of my sin grounded on sinful loving',
#  'or if it do not from those lips of thine',
#  'one of her featherd creatures broke away',
#  'whilst i thy babe chase thee afar behind',
#  'and would corrupt my saint to be a devil',
#  'and whether that my angel be turnd fiend',
#  ...]

# %% [markdown]
# ### Use Your Data Tool to Create Character Sequences
#
# We'll need the `create_char_sequences` method for this task. However, this method requires a parameter called `maxlen,` which is responsible for setting the maximum sequence length.
#
# So what would be a good sequence length, exactly?
#
# To answer that question, let's do some statistics!

# %%
def calc_stats(corpus):
  
    """
    Calculates statistics on the length of every line in the sonnets
    """
    
    # write a list comprehension that calculates each sonnets line length - save the results to `doc_lens` 

    # use NumPy to calculate and return the mean, median, std, max, min of the doc lens - all in one line of code

    # YOUR CODE HERE
    doc_lens = [len(x) for x in corpus]

    mean = np.mean(doc_lens)
    median = np.median(doc_lens)
    std = np.std(doc_lens)
    min = np.min(doc_lens)
    max = np.max(doc_lens)

    return mean, median, std, min, max

# %%
# sonnet line length statistics 
mean ,med, std, max_, min_ = calc_stats(clean_sonnets)
mean, med, std, max_, min_
# Out:
# (40.8784222737819, 41.0, 4.04121152010423, 27, 57)

# %%
# using the results of the sonnet line length statistics, use your judgement and select a value for maxlen
# use .create_char_sequences() to create sequences

# YOUR CODE HERE
maxlen = 40
dctk.create_char_sequences(clean_sonnets, maxlen=maxlen)
# Out:
# Created 18042 sequences.

# %% [markdown]
# Take a look at the `data_cleaning_toolkit_class.py` file.
#
# In the first four lines of code in the `create_char_sequences` method, class attributes `n_features` and `unique_chars` are created. Let's call them in the cells below.

# %%
# number of input features for our LSTM model
print(dctk.n_features)
# Out:
# 27

# %%
# unique characters that appear in our sonnets 
dctk.unique_chars
# Out:
# ['f',
#  'p',
#  'd',
#  'c',
#  'j',
#  'q',
#  'a',
#  'r',
#  'w',
#  's',
#  'z',
#  'h',
#  'g',
#  't',
#  'e',
#  'm',
#  'i',
#  ' ',
#  'v',
#  'o',
#  'l',
#  'x',
#  'u',
#  'y',
#  'k',
#  'n',
#  'b']

# %% [markdown]
# ## Time for Questions
#
# ----
# **Question 1:**
#
# Why is the `number of unique characters` (i.e., **dctk.unique_chars**) and the `number of model input features` (i.e., **dctk.n_features**) the same?
#
# **Hint:** The model that we will shortly build here is very similar to the text generation model we built in the guided project.

# %% [markdown]
# **Answer 1:**
#
# Because we're generating it by characters rather than words

# %% [markdown]
# **Question 2:**
#
# Take a look at the printout of `dctk.unique_chars` one more time. Notice that there is a white space.
#
# Why is it desirable to have a white space as a possible character to predict?

# %% [markdown]
# **Answer 2:**
#
# So that it generates spaces in between words.

# %% [markdown]
# ----

# %% [markdown]
# ### Use Our Data Tool to Create X and Y Splits
#
# You'll need the `create_X_and_Y` method for this task.

# %%
# TODO: provide a walkthrough of data_cleaning_toolkit with unit tests that check for understanding 
X, y = dctk.create_X_and_Y()

# %% [markdown]
# ![](https://miro.medium.com/max/891/0*jGB1CGQ9HdeUwlgB)

# %%
# notice that our input matrix isn't a matrix - it's a rank three tensor
X.shape
# Out:
# (18042, 40, 27)

# %% [markdown]
# In $X$.shape, we see three numbers (*n1*, *n2*, *n3*). What do these numbers mean?
#
# Well, *n1* tells us the number of samples that we have. But what about the other two?

# %%
# first index returns a signle sample, which we can see is a sequence 
first_sample_index = 0 
X[first_sample_index]
# Out:
# array([[ True, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %% [markdown]
# Notice that each sequence (i.e., $X[i]$ where $i$ is some index value) is `maxlen` long and has `dctk.n_features` number of features. Let's try to understand this shape better.

# %%
# each sequence is maxlen long and has dctk.n_features number of features
X[first_sample_index].shape
# Out:
# (40, 27)

# %% [markdown]
# **Each row corresponds to a character vector,** and there is `maxlen` number of character vectors.
#
# **Each column corresponds to a unique character,** and there are `dctk.n_features` number of features.

# %%
# let's index for a single character vector 
first_char_vect_index = 0
X[first_sample_index][first_char_vect_index]
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %% [markdown]
# Notice that there is a single `TRUE` value, and all the rest of the values are `FALSE`.
#
# This is a one-hot encoding for which character appears at each index within a sequence. Specifically, the cell above is looking at the first character in the sequence.
#
# Only a single character can appear as the first character in a sequence, so there will be a single `TRUE` value, and the rest will be `FALSE`.
#
# Let's say that `TRUE` appears in the $ith$ index; by  $ith$ index we mean some index in the general case. So how can we find out which character corresponds to?
#
# To answer this question, we need to use the character-to-integer look-up dictionaries.

# %%
# take a look at the index to character dictionary
# if a TRUE appears in the 0th index of a character vector,
# then we know that whatever char you see below next to the 0th key 
# is the character that character vector is endcoding for
dctk.int_char
# Out:
# {0: 'f',
#  1: 'p',
#  2: 'd',
#  3: 'c',
#  4: 'j',
#  5: 'q',
#  6: 'a',
#  7: 'r',
#  8: 'w',
#  9: 's',
#  10: 'z',
#  11: 'h',
#  12: 'g',
#  13: 't',
#  14: 'e',
#  15: 'm',
#  16: 'i',
#  17: ' ',
#  18: 'v',
#  19: 'o',
#  20: 'l',
#  21: 'x',
#  22: 'u',
#  23: 'y',
#  24: 'k',
#  25: 'n',
#  26: 'b'}

# %%
# let's look at an example to tie it all together

seq_len_counter = 0

# index for a single sample 
for seq_of_char_vects in X[first_sample_index]:
    
    # get index with max value, which will be the one TRUE value 
    index_with_TRUE_val = np.argmax(seq_of_char_vects)
    
    print (dctk.int_char[index_with_TRUE_val])
    
    seq_len_counter+=1
    
print ("Sequence length: {}".format(seq_len_counter))
# Out:
# f
# r
# o
# m
#
# f
# a
# i
# r
# e
# s
# t
#
# c
# r
# e
# a
# t
# u
# r
# e
# s
#
# w
# e
#
# d
# e
# s
# i
# r
# e
#
# i
# n
# c
# r
# e
# a
# s
# Sequence length: 40

# %% [markdown]
# ## Time for Questions
#
# ----
# **Question 1:**
#
# In your own words, how would you describe the numbers from the shape printout of `X.shape` to a classmate?

# %% [markdown]
# **Answer 1:**
#
# It is a three dimensional list, and basically its a lot of lists of 40 lists that all contain 27 boolean values to signify a certain letter

# %% [markdown]
# ----

# %% [markdown]
# ### Build a Text Generation Model
#
# Now that we have prepped our data (and understood that process), let's finally build out our character generation model, similar to what we did in the guided project.

# %%
def sample(preds, temperature=1.0):
    """
    Helper function to sample an index from a probability array
    """
    # convert preds to array 
    preds = np.asarray(preds).astype('float64')
    # scale values 
    preds = np.log(preds) / temperature
    # exponentiate values
    exp_preds = np.exp(preds)
    # this equation should look familar to you (hint: it's an activation function)
    preds = exp_preds / np.sum(exp_preds)
    # Draw samples from a multinomial distribution
    probas = np.random.multinomial(1, preds, 1)
    # return the index that corresponds to the max probability 
    return np.argmax(probas)

def on_epoch_end(epoch, _):
    """"
    Function invoked at the end of each epoch. Prints the text generated by our model.
    """
    
    print()
    print('----- Generating text after Epoch: %d' % epoch)
    

    # randomly pick a starting index 
    # will be used to take a random sequence of chars from `text`
    start_index = random.randint(0, len(text) - dctk.maxlen - 1)
    
    # this is our seed string (i.e. input seqeunece into the model)
    generated = ''

    # start the sentence at index `start_index` and include the next` dctk.maxlen` number of chars
    sentence = text[start_index: start_index + dctk.maxlen]

    # add to generated
    generated += sentence

    
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)
    
    # use model to predict what the next 40 chars should be that follow the seed string
    for i in range(40):

        # shape of a single sample in a rank 3 tensor 
        x_dims = (1, dctk.maxlen, dctk.n_features)
        # create an array of zeros with shape x_dims
        # recall that python considers zeros and boolean FALSE as the same
        x_pred = np.zeros(x_dims)

        # create a seq vector for our randomly select sequence 
        # i.e. create a numerical encoding for each char in the sequence 
        for t, char in enumerate(sentence):
            # for sample 0 in seq index t and character `char` encode a 1 (which is the same as a TRUE)
            x_pred[0, t, dctk.char_int[char]] = 1

        # next, take the seq vector and pass into model to get a prediction of what the next char should be 
        preds = model.predict(x_pred, verbose=0)[0]
        # use the sample helper function to get index for next char 
        next_index = sample(preds)
        # use look up dict to get next char 
        next_char = dctk.int_char[next_index]

        # append next char to sequence 
        sentence = sentence[1:] + next_char 
        
        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()

# %%
# need this for on_epoch_end()
text = " ".join(clean_sonnets)

# %%
# create callback object that will print out text generation at the end of each epoch 
# use for real-time monitoring of model performance
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %% [markdown]
# ----
# ### Train Model
#
# Build a text generation model using LSTMs. Feel free to reference the model used in the guided project.
#
# It is recommended that you train this model to at least 50 epochs (but more if you're computer can handle it).
#
# You are free to change up the architecture as you wish.
#
# Just in case you have difficultly training a model, there is a pre-trained model saved to a file called `trained_text_gen_model.h5` that you can load in (the same way that you learned how to load in Keras models in Sprint 2 Module 4).

# %%
from tensorflow.keras.optimizers import Adam

# %%
# build text generation model layer by layer 
# fit model

# YOUR CODE HERE
model = Sequential()
model.add(LSTM(
    256,
    input_shape=(dctk.maxlen, dctk.n_features),
    return_sequences=False
))
model.add(Dense(
    dctk.n_features,
    activation='softmax'
))
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.003))
model.fit(X, y, batch_size=128, epochs=200, callbacks=[print_callback])
# Out:
# Epoch 1/200
# 141/141 [==============================] - 17s 112ms/step - loss: 2.6858
#
# ----- Generating text after Epoch: 0
# ----- Generating with seed: " contains and that is this and this with"
#  contains and that is this and this withee uthe teali nau tbetmms os se di mngsa
# Epoch 2/200
# 141/141 [==============================] - 16s 115ms/step - loss: 2.2071
#
# ----- Generating text after Epoch: 1
# ----- Generating with seed: "alse womens fashion an eye more bright t"
# alse womens fashion an eye more bright toor arayntut tort reter voruls wor nos d
# Epoch 3/200
# 141/141 [==============================] - 16s 113ms/step - loss: 2.0287
#
# ----- Generating text after Epoch: 2
# ----- Generating with seed: "dead since i left you mine eye is in my "
# dead since i left you mine eye is in my des ewedrthka garess ow owler thaci thec
# Epoch 4/200
# 141/141 [==============================] - 16s 115ms/step - loss: 1.9100
#
# ----- Generating text after Epoch: 3
# ----- Generating with seed: " hungry ocean gain advantage on the king"
#  hungry ocean gain advantage on the kinghs as in my tul thoustoutain nates dat i
# Epoch 5/200
# 141/141 [==============================] - 16s 115ms/step - loss: 1.8115
#
# ----- Generating text after Epoch: 4
# ----- Generating with seed: "eated till nature as she wrought thee fe"
# eated till nature as she wrought thee feit they live i dey ale thit i noigh stir
# Epoch 6/200
# 141/141 [==============================] - 19s 133ms/step - loss: 1.7258
#
# ----- Generating text after Epoch: 5
# ----- Generating with seed: "ame thy love and love that still and the"
# ame thy love and love that still and these thy thounteth sew word focdey pridest
# Epoch 7/200
# 141/141 [==============================] - 17s 117ms/step - loss: 1.6439
#
# ----- Generating text after Epoch: 6
# ----- Generating with seed: "emd to me but hope of orphans and unfath"
# emd to me but hope of orphans and unfathers ears love and hyop membe make wey we
# Epoch 8/200
# 141/141 [==============================] - 16s 116ms/step - loss: 1.5522
#
# ----- Generating text after Epoch: 7
# ----- Generating with seed: "undivided loves are one so shall those b"
# undivided loves are one so shall those botktnwact duth acpite and withrese buine
# Epoch 9/200
# 141/141 [==============================] - 16s 113ms/step - loss: 1.4469
#
# ----- Generating text after Epoch: 8
# ----- Generating with seed: " the eye of scorn upon thy side against "
#  the eye of scorn upon thy side against thee fould acd my how congyess is it juu
# Epoch 10/200
# 141/141 [==============================] - 16s 115ms/step - loss: 1.3253
#
# ----- Generating text after Epoch: 9
# ----- Generating with seed: "ead since i left you mine eye is in my m"
# ead since i left you mine eye is in my more preathalss time len my love wath lov
# Epoch 11/200
# 141/141 [==============================] - 16s 114ms/step - loss: 1.1866
#
# ----- Generating text after Epoch: 10
# ----- Generating with seed: "o the view gord mine own thoughts sold c"
# o the view gord mine own thoughts sold car and toreum cay not dost net will that
# Epoch 12/200
# 141/141 [==============================] - 19s 132ms/step - loss: 1.0364
#
# ----- Generating text after Epoch: 11
# ----- Generating with seed: " welcome thrice more wished more rare be"
#  welcome thrice more wished more rare be agn a praidespoens thas is eyde more so
# Epoch 13/200
# 141/141 [==============================] - 17s 120ms/step - loss: 0.8862
#
# ----- Generating text after Epoch: 12
# ----- Generating with seed: " heir and beauty slanderd with a bastard"
#  heir and beauty slanderd with a bastard thine gind by colier a ploct so shals t
# Epoch 14/200
# 141/141 [==============================] - 17s 120ms/step - loss: 0.7451
#
# ----- Generating text after Epoch: 13
# ----- Generating with seed: "rld besides methinks are dead since i le"
# rld besides methinks are dead since i lend healt not to cruch shede time of ster
# Epoch 15/200
# 141/141 [==============================] - 16s 110ms/step - loss: 0.6353
#
# ----- Generating text after Epoch: 14
# ----- Generating with seed: "es and hopes to fears still losing when "
# es and hopes to fears still losing when wa bland sill that featta eyepily ti thy
# Epoch 16/200
# 141/141 [==============================] - 15s 110ms/step - loss: 0.5425
#
# ----- Generating text after Epoch: 15
# ----- Generating with seed: "aw you fresh which yet are green ah yet "
# aw you fresh which yet are green ah yet rove a fell with peccecouss deach her ow
# Epoch 17/200
# 141/141 [==============================] - 15s 110ms/step - loss: 0.4429
#
# ----- Generating text after Epoch: 16
# ----- Generating with seed: " show who moving others are themselves a"
#  show who moving others are themselves and the maker thee in thy brows and i the
# Epoch 18/200
# 141/141 [==============================] - 15s 109ms/step - loss: 0.3663
#
# ----- Generating text after Epoch: 17
# ----- Generating with seed: "past prime and sable curls all silvered "
# past prime and sable curls all silvered with to eyes is you for my rabe is when
# Epoch 19/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.2890
#
# ----- Generating text after Epoch: 18
# ----- Generating with seed: "doth half that glory to the sober west a"
# doth half that glory to the sober west and my tan sime love with living reap sin
# Epoch 20/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.2521
#
# ----- Generating text after Epoch: 19
# ----- Generating with seed: "est as fast as objects to his beams asse"
# est as fast as objects to his beams asseld for then zill my looks gourd will tho
# Epoch 21/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.2382
#
# ----- Generating text after Epoch: 20
# ----- Generating with seed: "ng that heavy saturn laughd and leapd wi"
# ng that heavy saturn laughd and leapd with awergse to ghat hiss do the ond expra
# Epoch 22/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.1923
#
# ----- Generating text after Epoch: 21
# ----- Generating with seed: "toln of both and to his robbery had anne"
# toln of both and to his robbery had annet megle my provild and readderad him que
# Epoch 23/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.1552
#
# ----- Generating text after Epoch: 22
# ----- Generating with seed: "ake so him i lose through my unkind abus"
# ake so him i lose through my unkind abuse that stook when can respecter praise m
# Epoch 24/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.1094
#
# ----- Generating text after Epoch: 23
# ----- Generating with seed: "livion yield his part of thee thy record"
# livion yield his part of thee thy record not a mease he our port ficd that wind
# Epoch 25/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0883
#
# ----- Generating text after Epoch: 24
# ----- Generating with seed: " so ill to set a form upon desired chang"
#  so ill to set a form upon desired change that my heart be thou gends me thee fa
# Epoch 26/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.0598
#
# ----- Generating text after Epoch: 25
# ----- Generating with seed: " in hideous night when i behold the viol"
#  in hideous night when i behold the violes thut woitd praise o contse where i am
# Epoch 27/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.0382
#
# ----- Generating text after Epoch: 26
# ----- Generating with seed: "and outward form would show it dead o ne"
# and outward form would show it dead o never true all the self thy can lorks thre
# Epoch 28/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0202
#
# ----- Generating text after Epoch: 27
# ----- Generating with seed: "way hiding thy bravery in their rotten s"
# way hiding thy bravery in their rotten self depare which likion me doth light be
# Epoch 29/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.0099
#
# ----- Generating text after Epoch: 28
# ----- Generating with seed: "d thee my best of love now all is done s"
# d thee my best of love now all is done shalt that which grouss on dear live with
# Epoch 30/200
# 141/141 [==============================] - 15s 109ms/step - loss: 0.0060
#
# ----- Generating text after Epoch: 29
# ----- Generating with seed: " seasons as thou fleets and do whateer t"
#  seasons as thou fleets and do whateer thy sid felfed beautys from the dost i mi
# Epoch 31/200
# 141/141 [==============================] - 15s 110ms/step - loss: 0.0043
#
# ----- Generating text after Epoch: 30
# ----- Generating with seed: "is loving thought had my friends muse gr"
# is loving thought had my friends muse grainst thou thesse thou havees on their b
# Epoch 32/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.0035
#
# ----- Generating text after Epoch: 31
# ----- Generating with seed: "my fate wishing me like to one more rich"
# my fate wishing me like to one more riches hare freai time havd eye that thou ca
# Epoch 33/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.0029
#
# ----- Generating text after Epoch: 32
# ----- Generating with seed: "thou art o therefore love be of thyself "
# thou art o therefore love be of thyself are friend cours and hell which sture ti
# Epoch 34/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0025
#
# ----- Generating text after Epoch: 33
# ----- Generating with seed: " cold bare ruind choirs where late the s"
#  cold bare ruind choirs where late the storst ton be thou plarse of the wornd i
# Epoch 35/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0022
#
# ----- Generating text after Epoch: 34
# ----- Generating with seed: "p in sheaves borne on the bier with whit"
# p in sheaves borne on the bier with whith the rumbe to thee i am forsures their
# Epoch 36/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.0019
#
# ----- Generating text after Epoch: 35
# ----- Generating with seed: "my heart in thy steel bosoms ward but th"
# my heart in thy steel bosoms ward but thinks for ey shall tan stare which thou s
# Epoch 37/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.0017
#
# ----- Generating text after Epoch: 36
# ----- Generating with seed: "ride of all his growth a vengeful canker"
# ride of all his growth a vengeful canker from the do the onding sain time thee i
# Epoch 38/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.0015
#
# ----- Generating text after Epoch: 37
# ----- Generating with seed: "n advantage on the kingdom of the shore "
# n advantage on the kingdom of the shore but dot know i ing can a falle of courd
# Epoch 39/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.0014
#
# ----- Generating text after Epoch: 38
# ----- Generating with seed: "s tomorrow see again and do not kill the"
# s tomorrow see again and do not kill the sturls the farecher than i amp and thou
# Epoch 40/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0012
#
# ----- Generating text after Epoch: 39
# ----- Generating with seed: " sail of his great verse bound for the p"
#  sail of his great verse bound for the pabr fair what do the ound a formert near
# Epoch 41/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.0011
#
# ----- Generating text after Epoch: 40
# ----- Generating with seed: "nd you and love are still my argument so"
# nd you and love are still my argument so my bet do kin by fie twath ples ores an
# Epoch 42/200
# 141/141 [==============================] - 16s 113ms/step - loss: 9.9977e-04
#
# ----- Generating text after Epoch: 41
# ----- Generating with seed: "d where they did proceed o know sweet lo"
# d where they did proceed o know sweet love for my veray with deease of thy from
# Epoch 43/200
# 141/141 [==============================] - 16s 111ms/step - loss: 9.0451e-04
#
# ----- Generating text after Epoch: 42
# ----- Generating with seed: "thousand victories once foild is from th"
# thousand victories once foild is from thy dost begus to preas that so plor the b
# Epoch 44/200
# 141/141 [==============================] - 16s 113ms/step - loss: 8.1984e-04
#
# ----- Generating text after Epoch: 43
# ----- Generating with seed: "e like to the lark at break of day arisi"
# e like to the lark at break of day arisid the sum more of the flooker she ange i
# Epoch 45/200
# 141/141 [==============================] - 16s 111ms/step - loss: 7.4529e-04
#
# ----- Generating text after Epoch: 44
# ----- Generating with seed: "ith white when lofty trees i see barren "
# ith white when lofty trees i see barren of hes beauty shou tooth will to were fa
# Epoch 46/200
# 141/141 [==============================] - 16s 112ms/step - loss: 6.7910e-04
#
# ----- Generating text after Epoch: 45
# ----- Generating with seed: " thee more to keep an adjunct to remembe"
#  thee more to keep an adjunct to rememberswoth this lander whence bire my lays n
# Epoch 47/200
# 141/141 [==============================] - 16s 112ms/step - loss: 6.1801e-04
#
# ----- Generating text after Epoch: 46
# ----- Generating with seed: "full flame should afterwards burn cleare"
# full flame should afterwards burn cleared be not day in in any blass did lose he
# Epoch 48/200
# 141/141 [==============================] - 16s 113ms/step - loss: 5.6311e-04
#
# ----- Generating text after Epoch: 47
# ----- Generating with seed: "ke you woe o ifi say you look upon this "
# ke you woe o ifi say you look upon this his thy spempy congress thou be ouch and
# Epoch 49/200
# 141/141 [==============================] - 16s 112ms/step - loss: 5.1795e-04
#
# ----- Generating text after Epoch: 48
# ----- Generating with seed: "so being full of your neercloying sweetn"
# so being full of your neercloying sweetn gase that in thy prive and all my brses
# Epoch 50/200
# 141/141 [==============================] - 16s 111ms/step - loss: 4.8110e-04
#
# ----- Generating text after Epoch: 49
# ----- Generating with seed: "d with seconds knows no art but mutual r"
# d with seconds knows no art but mutual re whine she love to preid no wore bathin
# Epoch 51/200
# 141/141 [==============================] - 16s 111ms/step - loss: 4.3504e-04
#
# ----- Generating text after Epoch: 50
# ----- Generating with seed: "yes of all posterity that wear this worl"
# yes of all posterity that wear this worls and steating that hind the weatst be u
# Epoch 52/200
# 141/141 [==============================] - 16s 114ms/step - loss: 3.9827e-04
#
# ----- Generating text after Epoch: 51
# ----- Generating with seed: "s tell pointing to each his thunder rain"
# s tell pointing to each his thunder rain where abe is thy can ray my life sunce
# Epoch 53/200
# 141/141 [==============================] - 16s 111ms/step - loss: 3.6285e-04
#
# ----- Generating text after Epoch: 52
# ----- Generating with seed: " physic did except past cure i am now re"
#  physic did except past cure i am now ressed in think in thy cabth respecter in
# Epoch 54/200
# 141/141 [==============================] - 16s 111ms/step - loss: 3.3161e-04
#
# ----- Generating text after Epoch: 53
# ----- Generating with seed: "mine only care art left the prey of ever"
# mine only care art left the prey of every hand but my life sunk put s bring st b
# Epoch 55/200
# 141/141 [==============================] - 16s 112ms/step - loss: 3.0342e-04
#
# ----- Generating text after Epoch: 54
# ----- Generating with seed: "the richproud cost of outworn buried age"
# the richproud cost of outworn buried age whos thou strough pird lioks to shall g
# Epoch 56/200
# 141/141 [==============================] - 16s 111ms/step - loss: 2.7875e-04
#
# ----- Generating text after Epoch: 55
# ----- Generating with seed: " this change is my invention spent three"
#  this change is my invention spent threem doth light trut thy cannd chere will b
# Epoch 57/200
# 141/141 [==============================] - 16s 111ms/step - loss: 2.5635e-04
#
# ----- Generating text after Epoch: 56
# ----- Generating with seed: "ealth mayst know times thievish progress"
# ealth mayst know times thievish progress to his gindins rince shee the lack fath
# Epoch 58/200
# 141/141 [==============================] - 16s 112ms/step - loss: 2.3597e-04
#
# ----- Generating text after Epoch: 57
# ----- Generating with seed: "rses be and having thee of all mens prid"
# rses be and having thee of all mens pride theee faireh teary sur ound brivild a
# Epoch 59/200
# 141/141 [==============================] - 16s 112ms/step - loss: 2.1701e-04
#
# ----- Generating text after Epoch: 58
# ----- Generating with seed: "w far a modern quill doth come too short"
# w far a modern quill doth come too short and stmat aghpoors doth beauty shall in
# Epoch 60/200
# 141/141 [==============================] - 16s 112ms/step - loss: 2.0034e-04
#
# ----- Generating text after Epoch: 59
# ----- Generating with seed: "k beshrew that heart that makes my heart"
# k beshrew that heart that makes my heart in thy cantl in thee deepine the onere
# Epoch 61/200
# 141/141 [==============================] - 16s 113ms/step - loss: 1.9068e-04
#
# ----- Generating text after Epoch: 60
# ----- Generating with seed: "rove loves fire heats water water cools "
# rove loves fire heats water water cools dots liftuld tu thine still my love my l
# Epoch 62/200
# 141/141 [==============================] - 16s 112ms/step - loss: 1.4886
#
# ----- Generating text after Epoch: 61
# ----- Generating with seed: "gry eyes even till they wink with fulnes"
# gry eyes even till they wink with fulnes may than peave eart wo th thme some tha
# Epoch 63/200
# 141/141 [==============================] - 16s 113ms/step - loss: 1.6172
#
# ----- Generating text after Epoch: 62
# ----- Generating with seed: "e all my poverty and yet love knows it i"
# e all my poverty and yet love knows it it ad him you dobe thought and will this
# Epoch 64/200
# 141/141 [==============================] - 19s 132ms/step - loss: 1.3970
#
# ----- Generating text after Epoch: 63
# ----- Generating with seed: " enjoys it but beautys waste hath in the"
#  enjoys it but beautys waste hath in the could a time thee werll that sake excou
# Epoch 65/200
# 141/141 [==============================] - 16s 111ms/step - loss: 1.1844
#
# ----- Generating text after Epoch: 64
# ----- Generating with seed: "i under my transgression bow unless my n"
# i under my transgression bow unless my nove my love to thich thy goor were beari
# Epoch 66/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.9598
#
# ----- Generating text after Epoch: 65
# ----- Generating with seed: "me then and wish i were renewd whilst li"
# me then and wish i were renewd whilst live the aterlsesseousl forseing in thind
# Epoch 67/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.7427
#
# ----- Generating text after Epoch: 66
# ----- Generating with seed: "ry within that pen doth dwell that to hi"
# ry within that pen doth dwell that to his hankir of my selfk or supt gike thee f
# Epoch 68/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.5579
#
# ----- Generating text after Epoch: 67
# ----- Generating with seed: "sistance in my verse as every alien pen "
# sistance in my verse as every alien pen stere fight threrven eye in the lon to o
# Epoch 69/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.4270
#
# ----- Generating text after Epoch: 68
# ----- Generating with seed: "year would make the world away let those"
# year would make the world away let those to this mare that in haps speak wills t
# Epoch 70/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.3368
#
# ----- Generating text after Epoch: 69
# ----- Generating with seed: "et the lease of my true love control sup"
# et the lease of my true love control suplect thou worth sweatst to shome love aw
# Epoch 71/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.2621
#
# ----- Generating text after Epoch: 70
# ----- Generating with seed: "they have devisd what strained touches r"
# they have devisd what strained touches ree where abd wied all bats you doth live
# Epoch 72/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.2162
#
# ----- Generating text after Epoch: 71
# ----- Generating with seed: " shines so how would i say mine eyes be "
#  shines so how would i say mine eyes be int to when came that deades wroncs did
# Epoch 73/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.1610
#
# ----- Generating text after Epoch: 72
# ----- Generating with seed: "that my name receives a brand and almost"
# that my name receives a brand and almost whigh doun time chere faire himffersed
# Epoch 74/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.1298
#
# ----- Generating text after Epoch: 73
# ----- Generating with seed: "each check without accusing you of injur"
# each check without accusing you of injurged figh the peek wher that thine userth
# Epoch 75/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.0955
#
# ----- Generating text after Epoch: 74
# ----- Generating with seed: "ve looks fresh and death to me subscribe"
# ve looks fresh and death to me subscribe with eart andestrich own live is that i
# Epoch 76/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0819
#
# ----- Generating text after Epoch: 75
# ----- Generating with seed: " set and you in grecian tires are painte"
#  set and you in grecian tires are painted fell i drinks as that recoose seet the
# Epoch 77/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.0751
#
# ----- Generating text after Epoch: 76
# ----- Generating with seed: "w have mine eyes out of their spheres be"
# w have mine eyes out of their spheres be nered is stay store to the ourst in thy
# Epoch 78/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.0622
#
# ----- Generating text after Epoch: 77
# ----- Generating with seed: "eggard of blood to blush through lively "
# eggard of blood to blush through lively all mand assmy mine to carnt thuse paie
# Epoch 79/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.0632
#
# ----- Generating text after Epoch: 78
# ----- Generating with seed: "hose are free then beauteous niggard why"
# hose are free then beauteous niggard why to bear you port night in evat words en
# Epoch 80/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.0678
#
# ----- Generating text after Epoch: 79
# ----- Generating with seed: "n to thy pure and most most loving breas"
# n to thy pure and most most loving breas of mose that vare be nor doth looks loc
# Epoch 81/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.0857
#
# ----- Generating text after Epoch: 80
# ----- Generating with seed: "ay deaths second self that seals up all "
# ay deaths second self that seals up all ifth three thought beautys greants and h
# Epoch 82/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.2251
#
# ----- Generating text after Epoch: 81
# ----- Generating with seed: "u wouldst use the strength of all thy st"
# u wouldst use the strength of all thy strought that verse to oe any apcuend and
# Epoch 83/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.3073
#
# ----- Generating text after Epoch: 82
# ----- Generating with seed: "ourselfs decease when your sweet issue y"
# ourselfs decease when your sweet issue you were but shades the dustrough my mude
# Epoch 84/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.2119
#
# ----- Generating text after Epoch: 83
# ----- Generating with seed: "lander doth but approve thy worth the gr"
# lander doth but approve thy worth the gror losbrince of the seall of mation lacu
# Epoch 85/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.1177
#
# ----- Generating text after Epoch: 84
# ----- Generating with seed: "anners holds her still while comments of"
# anners holds her still while comments of when ty uen but but plen me pesealth be
# Epoch 86/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0552
#
# ----- Generating text after Epoch: 85
# ----- Generating with seed: "gd to thy will myself ill forfeit so tha"
# gd to thy will myself ill forfeit so that wanto the time bath of folfermint exce
# Epoch 87/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0229
#
# ----- Generating text after Epoch: 86
# ----- Generating with seed: "n wrongfully disgracd and strength by li"
# n wrongfully disgracd and strength by live in lest doth wine a from the dost bes
# Epoch 88/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0095
#
# ----- Generating text after Epoch: 87
# ----- Generating with seed: "more acknowledge thee lest my bewailed g"
# more acknowledge thee lest my bewailed guce your mong a tmans and lovell fers al
# Epoch 89/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0055
#
# ----- Generating text after Epoch: 88
# ----- Generating with seed: "est as those two mourning eyes become th"
# est as those two mourning eyes become that mare that thy unow sin leass the sull
# Epoch 90/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0042
#
# ----- Generating text after Epoch: 89
# ----- Generating with seed: "t the dust and injury of age nor gives t"
# t the dust and injury of age nor gives to esst though shall see this bare that m
# Epoch 91/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.0034
#
# ----- Generating text after Epoch: 90
# ----- Generating with seed: "de three beauteous springs to yellow aut"
# de three beauteous springs to yellow autuming the world beart for then fare in m
# Epoch 92/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.0029
#
# ----- Generating text after Epoch: 91
# ----- Generating with seed: "lour it had stoln from thee where art th"
# lour it had stoln from thee where art thou dxen hus candin he dear with which pl
# Epoch 93/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.0025
#
# ----- Generating text after Epoch: 92
# ----- Generating with seed: "g this wide universe i call save thou my"
# g this wide universe i call save thou my seeming weere even such couron one in t
# Epoch 94/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0022
#
# ----- Generating text after Epoch: 93
# ----- Generating with seed: " knowst i love her and for my sake even "
#  knowst i love her and for my sake even say thou thut is thy wilthound thy unbri
# Epoch 95/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.0019
#
# ----- Generating text after Epoch: 94
# ----- Generating with seed: " leave my love alone ah wherefore with i"
#  leave my love alone ah wherefore with i bains non thee hapl now the heapthere s
# Epoch 96/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.0017
#
# ----- Generating text after Epoch: 95
# ----- Generating with seed: "store harsh featureless and rude barrenl"
# store harsh featureless and rude barrenl watere by the chind the world thou dest
# Epoch 97/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0015
#
# ----- Generating text after Epoch: 96
# ----- Generating with seed: "to leave for nothing all thy sum of good"
# to leave for nothing all thy sum of good with untake thou mine sweet beautys fro
# Epoch 98/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0013
#
# ----- Generating text after Epoch: 97
# ----- Generating with seed: " in so profound abysm i throw all care o"
#  in so profound abysm i throw all care of thy touth thee are you both hive wele
# Epoch 99/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0012
#
# ----- Generating text after Epoch: 98
# ----- Generating with seed: "n your wakend hate since my appeal says "
# n your wakend hate since my appeal says to styer thee in thee our mike hem and s
# Epoch 100/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0011
#
# ----- Generating text after Epoch: 99
# ----- Generating with seed: "e the bath for my help lies where cupid "
# e the bath for my help lies where cupid y the fensle dook what by your self to s
# Epoch 101/200
# 141/141 [==============================] - 16s 112ms/step - loss: 9.7453e-04
#
# ----- Generating text after Epoch: 100
# ----- Generating with seed: " are raven black her eyes so suited and "
#  are raven black her eyes so suited and grean and willd be though thee seeit dot
# Epoch 102/200
# 141/141 [==============================] - 16s 113ms/step - loss: 8.8264e-04
#
# ----- Generating text after Epoch: 101
# ----- Generating with seed: "aladies a sovereign cure but at my mistr"
# aladies a sovereign cure but at my mistress of thy errom the dead kild my love w
# Epoch 103/200
# 141/141 [==============================] - 16s 114ms/step - loss: 8.0073e-04
#
# ----- Generating text after Epoch: 102
# ----- Generating with seed: "ll of different flowers in odour and in "
# ll of different flowers in odour and in the llar he worn both side and sheme fai
# Epoch 104/200
# 141/141 [==============================] - 16s 114ms/step - loss: 7.2801e-04
#
# ----- Generating text after Epoch: 103
# ----- Generating with seed: "ge hide stealing unseen to west with thi"
# ge hide stealing unseen to west with thine with all the deat read his lights and
# Epoch 105/200
# 141/141 [==============================] - 16s 114ms/step - loss: 6.6331e-04
#
# ----- Generating text after Epoch: 104
# ----- Generating with seed: "ngs tan sacred beauty blunt the sharpst "
# ngs tan sacred beauty blunt the sharpst thou woith thee thou shall mad of mare t
# Epoch 106/200
# 141/141 [==============================] - 16s 114ms/step - loss: 6.0487e-04
#
# ----- Generating text after Epoch: 105
# ----- Generating with seed: "his lovekindling fire did quickly steep "
# his lovekindling fire did quickly steep and that roch first when stanes rove now
# Epoch 107/200
# 141/141 [==============================] - 16s 113ms/step - loss: 5.5284e-04
#
# ----- Generating text after Epoch: 106
# ----- Generating with seed: "ears a face that overgoes my blunt inven"
# ears a face that overgoes my blunt inventin  ull my bosy sink thut leves to so t
# Epoch 108/200
# 141/141 [==============================] - 16s 113ms/step - loss: 5.0512e-04
#
# ----- Generating text after Epoch: 107
# ----- Generating with seed: "han time wastes life so thou preventst h"
# han time wastes life so thou preventst hill pision corirund in the brace hou and
# Epoch 109/200
# 141/141 [==============================] - 16s 114ms/step - loss: 4.6261e-04
#
# ----- Generating text after Epoch: 108
# ----- Generating with seed: "mine eye as interest of the dead which n"
# mine eye as interest of the dead which now the tound and he san she thend exthen
# Epoch 110/200
# 141/141 [==============================] - 16s 114ms/step - loss: 4.2390e-04
#
# ----- Generating text after Epoch: 109
# ----- Generating with seed: "nd so the general of hot desire was slee"
# nd so the general of hot desire was sleed hull sain thee for a savdel that is th
# Epoch 111/200
# 141/141 [==============================] - 16s 113ms/step - loss: 3.8875e-04
#
# ----- Generating text after Epoch: 110
# ----- Generating with seed: " of thee now this illwresting world is g"
#  of thee now this illwresting world is gate and lovely whilct that which the tre
# Epoch 112/200
# 141/141 [==============================] - 16s 115ms/step - loss: 3.5680e-04
#
# ----- Generating text after Epoch: 111
# ----- Generating with seed: " keeps thee to this purpose that her ski"
#  keeps thee to this purpose that her sking the robrund the sull new looked i thi
# Epoch 113/200
# 141/141 [==============================] - 16s 114ms/step - loss: 3.2763e-04
#
# ----- Generating text after Epoch: 112
# ----- Generating with seed: " it thus anew to greet i hate she alterd"
#  it thus anew to greet i hate she alterd with take a calld be stoll forsuove no
# Epoch 114/200
# 141/141 [==============================] - 17s 117ms/step - loss: 3.0142e-04
#
# ----- Generating text after Epoch: 113
# ----- Generating with seed: "g trimmd in jollity and purest faith unh"
# g trimmd in jollity and purest faith unhomenlf carme bace in poss doth live long
# Epoch 115/200
# 141/141 [==============================] - 16s 113ms/step - loss: 2.7720e-04
#
# ----- Generating text after Epoch: 114
# ----- Generating with seed: "elight i may not evermore acknowledge th"
# elight i may not evermore acknowledge thought that which stent that strould thy
# Epoch 116/200
# 141/141 [==============================] - 16s 113ms/step - loss: 2.5509e-04
#
# ----- Generating text after Epoch: 115
# ----- Generating with seed: "i love thee not when i against myself wi"
# i love thee not when i against myself will me toutheast wo loves thee my meed of
# Epoch 117/200
# 141/141 [==============================] - 16s 113ms/step - loss: 2.3484e-04
#
# ----- Generating text after Epoch: 116
# ----- Generating with seed: "t the very worst of fortunes might and o"
# t the very worst of fortunes might and oteer and a mate mades ald to the wire wh
# Epoch 118/200
# 141/141 [==============================] - 16s 114ms/step - loss: 2.1652e-04
#
# ----- Generating text after Epoch: 117
# ----- Generating with seed: "u turn back and my loud crying still two"
# u turn back and my loud crying still twoor my stull mads thoughts contren beauty
# Epoch 119/200
# 141/141 [==============================] - 16s 114ms/step - loss: 1.9940e-04
#
# ----- Generating text after Epoch: 118
# ----- Generating with seed: "im but copy what in you is writ not maki"
# im but copy what in you is writ not making wise to thee with preise than will in
# Epoch 120/200
# 141/141 [==============================] - 16s 115ms/step - loss: 1.8436e-04
#
# ----- Generating text after Epoch: 119
# ----- Generating with seed: "leep in dreams they look on thee and dar"
# leep in dreams they look on thee and darkes rear rince awame by fees their have
# Epoch 121/200
# 141/141 [==============================] - 19s 137ms/step - loss: 1.9752e-04
#
# ----- Generating text after Epoch: 120
# ----- Generating with seed: "g his purity with her foul pride and whe"
# g his purity with her foul pride and when came be good of love nou lave your not
# Epoch 122/200
# 141/141 [==============================] - 16s 113ms/step - loss: 1.5046
#
# ----- Generating text after Epoch: 121
# ----- Generating with seed: "rgot am of my self all tyrant for thy sa"
# rgot am of my self all tyrant for thy sakeres recult as those should thou dost r
# Epoch 123/200
# 141/141 [==============================] - 16s 114ms/step - loss: 1.0653
#
# ----- Generating text after Epoch: 122
# ----- Generating with seed: "ar that brightness doth not grace the da"
# ar that brightness doth not grace the day my spenk accould not to the e that to
# Epoch 124/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.6069
#
# ----- Generating text after Epoch: 123
# ----- Generating with seed: "t gracious and in my will no fair accept"
# t gracious and in my will no fair accept doth sabutist or ass rectoris are boury
# Epoch 125/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.3265
#
# ----- Generating text after Epoch: 124
# ----- Generating with seed: "outh in every thing that heavy saturn la"
# outh in every thing that heavy saturn laiss own summen shing throwor for what de
# Epoch 126/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.1815
#
# ----- Generating text after Epoch: 125
# ----- Generating with seed: "s have drawn thy shape and thine for me "
# s have drawn thy shape and thine for me sow all praise encursel that thy und cou
# Epoch 127/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.1110
#
# ----- Generating text after Epoch: 126
# ----- Generating with seed: "istake my view the sun itself sees not t"
# istake my view the sun itself sees not tight that ange for men bace but doan anv
# Epoch 128/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0613
#
# ----- Generating text after Epoch: 127
# ----- Generating with seed: "is that you for love speak well of me un"
# is that you for love speak well of me unts propsen tith thy his maken i my thee
# Epoch 129/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0324
#
# ----- Generating text after Epoch: 128
# ----- Generating with seed: " thou survive my wellcontented day when "
#  thou survive my wellcontented day when the plect thut leasures can she thend do
# Epoch 130/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0179
#
# ----- Generating text after Epoch: 129
# ----- Generating with seed: " ignorance whilst i alone did call upon "
#  ignorance whilst i alone did call upon heiss love how to stranks a deadill of d
# Epoch 131/200
# 141/141 [==============================] - 17s 117ms/step - loss: 0.0097
#
# ----- Generating text after Epoch: 130
# ----- Generating with seed: "ted as a swallowd bait on purpose laid t"
# ted as a swallowd bait on purpose laid than huss is every beautes from my whet e
# Epoch 132/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.0060
#
# ----- Generating text after Epoch: 131
# ----- Generating with seed: "indness oaths of thy love thy truth thy "
# indness oaths of thy love thy truth thy sweat sud the worth and pitelt depersen
# Epoch 133/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0045
#
# ----- Generating text after Epoch: 132
# ----- Generating with seed: "prevent our maladies unseen we sicken to"
# prevent our maladies unseen we sicken to their mane of thy from then have i i n
# Epoch 134/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.0036
#
# ----- Generating text after Epoch: 133
# ----- Generating with seed: "ous grace in whom all ill well shows kil"
# ous grace in whom all ill well shows kilf from thy babut in a ondul is ver hath
# Epoch 135/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0030
#
# ----- Generating text after Epoch: 134
# ----- Generating with seed: "which works on leases of shortnumberd ho"
# which works on leases of shortnumberd hos wrong mad and mak of mate of the marst
# Epoch 136/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0026
#
# ----- Generating text after Epoch: 135
# ----- Generating with seed: "flowers distilld though they with winter"
# flowers distilld though they with winter mose repear les of dookes wo the wine t
# Epoch 137/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0022
#
# ----- Generating text after Epoch: 136
# ----- Generating with seed: "nd burn the longlivd phoenix in her bloo"
# nd burn the longlivd phoenix in her blood aname me dost but pleast to the were h
# Epoch 138/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0019
#
# ----- Generating text after Epoch: 137
# ----- Generating with seed: "art gentle thou art and therefore to be "
# art gentle thou art and therefore to be aye the earth couch andiquectes and bles
# Epoch 139/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0017
#
# ----- Generating text after Epoch: 138
# ----- Generating with seed: "se waste blanks and thou shalt find thos"
# se waste blanks and thou shalt find those fareth my self throw so deppart love t
# Epoch 140/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.0015
#
# ----- Generating text after Epoch: 139
# ----- Generating with seed: "e can sit your own glass shows you when "
# e can sit your own glass shows you when ty se then soll the farent be fore than
# Epoch 141/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0013
#
# ----- Generating text after Epoch: 140
# ----- Generating with seed: "at first more strong far greater so i re"
# at first more strong far greater so i rent no being said truth short to compile
# Epoch 142/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0012
#
# ----- Generating text after Epoch: 141
# ----- Generating with seed: "ars no marvel then though i mistake my v"
# ars no marvel then though i mistake my vetses seem die burn guade blowd of mase
# Epoch 143/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.0010
#
# ----- Generating text after Epoch: 142
# ----- Generating with seed: "gs tan sacred beauty blunt the sharpst i"
# gs tan sacred beauty blunt the sharpst it or wothing whos bs id the formor me do
# Epoch 144/200
# 141/141 [==============================] - 16s 113ms/step - loss: 9.2926e-04
#
# ----- Generating text after Epoch: 143
# ----- Generating with seed: "that myself bring water for my stain nev"
# that myself bring water for my stain never faulls of ploosts for subing sell ros
# Epoch 145/200
# 141/141 [==============================] - 16s 112ms/step - loss: 8.3369e-04
#
# ----- Generating text after Epoch: 144
# ----- Generating with seed: "rest creatures we desire increase that t"
# rest creatures we desire increase that thine then myerss whene in my lovies thus
# Epoch 146/200
# 141/141 [==============================] - 16s 114ms/step - loss: 7.4945e-04
#
# ----- Generating text after Epoch: 145
# ----- Generating with seed: " beautys doom and date when i consider e"
#  beautys doom and date when i consider evern and all the thine is my doth for my
# Epoch 147/200
# 141/141 [==============================] - 16s 112ms/step - loss: 6.7522e-04
#
# ----- Generating text after Epoch: 146
# ----- Generating with seed: "est how to make one twain by praising hi"
# est how to make one twain by praising him fare his wart when strangy on my love
# Epoch 148/200
# 141/141 [==============================] - 16s 112ms/step - loss: 6.1011e-04
#
# ----- Generating text after Epoch: 147
# ----- Generating with seed: "rogress to eternity look what thy memory"
# rogress to eternity look what thy memory when th usppater tonter thee hand guint
# Epoch 149/200
# 141/141 [==============================] - 16s 112ms/step - loss: 5.5315e-04
#
# ----- Generating text after Epoch: 148
# ----- Generating with seed: "oaned moan which i new pay as if not pai"
# oaned moan which i new pay as if not pain the ment of lovell faulse by me doth f
# Epoch 150/200
# 141/141 [==============================] - 16s 112ms/step - loss: 5.1211e-04
#
# ----- Generating text after Epoch: 149
# ----- Generating with seed: " as thy sweet self growst if nature sove"
#  as thy sweet self growst if nature soversed berne he love to the waneres on be
# Epoch 151/200
# 141/141 [==============================] - 16s 112ms/step - loss: 5.4165e-04
#
# ----- Generating text after Epoch: 150
# ----- Generating with seed: "uld i haste me thence till i return of p"
# uld i haste me thence till i return of praise habl and all the rich when the rec
# Epoch 152/200
# 141/141 [==============================] - 16s 112ms/step - loss: 5.2209e-04
#
# ----- Generating text after Epoch: 151
# ----- Generating with seed: "lourish set on youth and delves the para"
# lourish set on youth and delves the parale i bling as prtise to my antequeal gha
# Epoch 153/200
# 141/141 [==============================] - 16s 112ms/step - loss: 1.0181
#
# ----- Generating text after Epoch: 152
# ----- Generating with seed: "th his windows glazed with thine eyes no"
# th his windows glazed with thine eyes not son it it heavens breat deavint hemoor
# Epoch 154/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.6752
#
# ----- Generating text after Epoch: 153
# ----- Generating with seed: "in how far i toil still farther off from"
# in how far i toil still farther off from tis when stould go thy mine thou secan
# Epoch 155/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.3220
#
# ----- Generating text after Epoch: 154
# ----- Generating with seed: "arts workings be thy looks should nothin"
# arts workings be thy looks should nothing dead of mad and speak af my life sulle
# Epoch 156/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.1592
#
# ----- Generating text after Epoch: 155
# ----- Generating with seed: "s to the weary night dost thou desire my"
# s to the weary night dost thou desire my limbunys provily new now be thou love a
# Epoch 157/200
# 141/141 [==============================] - 16s 117ms/step - loss: 0.0725
#
# ----- Generating text after Epoch: 156
# ----- Generating with seed: "led that censures falsely what they see "
# led that censures falsely what they see truch im for their recves to have for th
# Epoch 158/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0340
#
# ----- Generating text after Epoch: 157
# ----- Generating with seed: "as the rich whose blessed key can bring "
# as the rich whose blessed key can bring a onst the heapt of my the own geast wor
# Epoch 159/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.0154
#
# ----- Generating text after Epoch: 158
# ----- Generating with seed: "rs down and on just proof surmise accumu"
# rs down and on just proof surmise accumuly amosswd do think ghought thuse that i
# Epoch 160/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.0081
#
# ----- Generating text after Epoch: 159
# ----- Generating with seed: "hen tyrants crests and tombs of brass ar"
# hen tyrants crests and tombs of brass are spine ones ruil the flower for all man
# Epoch 161/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0054
#
# ----- Generating text after Epoch: 160
# ----- Generating with seed: " fair and thought thee bright who art as"
#  fair and thought thee bright who art as be now in my dren his lawas what thou s
# Epoch 162/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.0041
#
# ----- Generating text after Epoch: 161
# ----- Generating with seed: " thing they see for i have sworn thee fa"
#  thing they see for i have sworn thee farch but proiged and signt the grect of y
# Epoch 163/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0033
#
# ----- Generating text after Epoch: 162
# ----- Generating with seed: "nd haply of our old acquaintance tell fo"
# nd haply of our old acquaintance tell for my name in thy praise he raiked epplid
# Epoch 164/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0027
#
# ----- Generating text after Epoch: 163
# ----- Generating with seed: "he proud full sail of his great verse bo"
# he proud full sail of his great verse boun and you inamy vire that in the nrapl
# Epoch 165/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.0023
#
# ----- Generating text after Epoch: 164
# ----- Generating with seed: "r at a frown they in their glory die the"
# r at a frown they in their glory die the obres dreaser from mish cind full to th
# Epoch 166/200
# 141/141 [==============================] - 16s 116ms/step - loss: 0.0020
#
# ----- Generating text after Epoch: 165
# ----- Generating with seed: "eeds to pry to find out shames and idle "
# eeds to pry to find out shames and idle that we delace one to slander when they
# Epoch 167/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0017
#
# ----- Generating text after Epoch: 166
# ----- Generating with seed: "that i am fled from this vile world with"
# that i am fled from this vile world with men pen you so the o woress doth beat f
# Epoch 168/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.0015
#
# ----- Generating text after Epoch: 167
# ----- Generating with seed: "all her fading sweets but i forbid thee "
# all her fading sweets but i forbid thee of they he mane and all the fent as form
# Epoch 169/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.0013
#
# ----- Generating text after Epoch: 168
# ----- Generating with seed: "es truth and nothing stands but for his "
# es truth and nothing stands but for his that sience from the for that shill she
# Epoch 170/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.0012
#
# ----- Generating text after Epoch: 169
# ----- Generating with seed: "es foregone and heavily from woe to woe "
# es foregone and heavily from woe to woe tenge mace of from the far a buidy conce
# Epoch 171/200
# 141/141 [==============================] - 17s 120ms/step - loss: 0.0010
#
# ----- Generating text after Epoch: 170
# ----- Generating with seed: "s which in my bosoms shop is hanging sti"
# s which in my bosoms shop is hanging stind habl ng false un with greasure theeie
# Epoch 172/200
# 141/141 [==============================] - 16s 113ms/step - loss: 9.0731e-04
#
# ----- Generating text after Epoch: 171
# ----- Generating with seed: "s brow feeds on the rarities of natures "
# s brow feeds on the rarities of natures to hear which plece th the gainte world
# Epoch 173/200
# 141/141 [==============================] - 16s 113ms/step - loss: 8.0954e-04
#
# ----- Generating text after Epoch: 172
# ----- Generating with seed: "erd such wealth brings that then i scorn"
# erd such wealth brings that then i scorndoun with vewn to be thee that my cours
# Epoch 174/200
# 141/141 [==============================] - 16s 113ms/step - loss: 7.2546e-04
#
# ----- Generating text after Epoch: 173
# ----- Generating with seed: "d what strained touches rhetoric can len"
# d what strained touches rhetoric can len he deares and the raise thr propild wit
# Epoch 175/200
# 141/141 [==============================] - 16s 113ms/step - loss: 8.2190e-04
#
# ----- Generating text after Epoch: 174
# ----- Generating with seed: " that god forbid that made me first your"
#  that god forbid that made me first your monc put my cube which you thought but
# Epoch 176/200
# 141/141 [==============================] - 16s 113ms/step - loss: 7.0916e-04
#
# ----- Generating text after Epoch: 175
# ----- Generating with seed: "n from hence your memory death cannot ta"
# n from hence your memory death cannot take a copserp apcetyoun and i ameavest be
# Epoch 177/200
# 141/141 [==============================] - 17s 117ms/step - loss: 0.0065
#
# ----- Generating text after Epoch: 176
# ----- Generating with seed: "hours to crave being your vassal bound t"
# hours to crave being your vassal bound the rem the rum thou seme of show aday be
# Epoch 178/200
# 141/141 [==============================] - 17s 117ms/step - loss: 0.9237
#
# ----- Generating text after Epoch: 177
# ----- Generating with seed: "ire shall burn the living record of your"
# ire shall burn the living record of your nect end in the batt new lake my your t
# Epoch 179/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.3718
#
# ----- Generating text after Epoch: 178
# ----- Generating with seed: "e supposing thou art true like a deceive"
# e supposing thou art true like a deceive there and i hall ny folling thy dresend
# Epoch 180/200
# 141/141 [==============================] - 17s 118ms/step - loss: 0.1550
#
# ----- Generating text after Epoch: 179
# ----- Generating with seed: "en dreams do show thee me if the dull su"
# en dreams do show thee me if the dull such a gumbuter prizill livesur aft my sto
# Epoch 181/200
# 141/141 [==============================] - 16s 116ms/step - loss: 0.0676
#
# ----- Generating text after Epoch: 180
# ----- Generating with seed: " selflove to stop posterity thou art thy"
#  selflove to stop posterity thou art thy are be noth fair a cuild ne my looks o
# Epoch 182/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0277
#
# ----- Generating text after Epoch: 181
# ----- Generating with seed: "isond pride blessed are you whose worthi"
# isond pride blessed are you whose worthin conts dithe so thing the marst thuselp
# Epoch 183/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0124
#
# ----- Generating text after Epoch: 182
# ----- Generating with seed: "ope with what i most enjoy contented lea"
# ope with what i most enjoy contented leas rid my can lone hand make that my can
# Epoch 184/200
# 141/141 [==============================] - 17s 117ms/step - loss: 0.0068
#
# ----- Generating text after Epoch: 183
# ----- Generating with seed: "teal his treasure now counting best to b"
# teal his treasure now counting best to be ay this grown bade by me than stall i
# Epoch 185/200
# 141/141 [==============================] - 16s 116ms/step - loss: 0.0046
#
# ----- Generating text after Epoch: 184
# ----- Generating with seed: " spite take all my comfort of thy worth "
#  spite take all my comfort of thy worth a cooth doth point sies love white i thi
# Epoch 186/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0036
#
# ----- Generating text after Epoch: 185
# ----- Generating with seed: "be false and yet i know it not so shall "
# be false and yet i know it not so shall the finder which sup so doth live that t
# Epoch 187/200
# 141/141 [==============================] - 18s 125ms/step - loss: 0.0029
#
# ----- Generating text after Epoch: 186
# ----- Generating with seed: "ul then striving to mend to mar the subj"
# ul then striving to mend to mar the subjurdes me ass you mind and stall frow off
# Epoch 188/200
# 141/141 [==============================] - 17s 120ms/step - loss: 0.0024
#
# ----- Generating text after Epoch: 187
# ----- Generating with seed: "ke hands to torture me the one by toil t"
# ke hands to torture me the one by toil thou make thou madite some savey to thy s
# Epoch 189/200
# 141/141 [==============================] - 17s 117ms/step - loss: 0.0021
#
# ----- Generating text after Epoch: 188
# ----- Generating with seed: " unthrifts dear my love you know you had"
#  unthrifts dear my love you know you hade that my cruel such a bourmen cay my co
# Epoch 190/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0018
#
# ----- Generating text after Epoch: 189
# ----- Generating with seed: "he style and arts with thy sweet graces "
# he style and arts with thy sweet graces gut when sterl with things thou in thee
# Epoch 191/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0015
#
# ----- Generating text after Epoch: 190
# ----- Generating with seed: "eyes have errd and to this false plague "
# eyes have errd and to this false plague of the earll mand and submer both couls
# Epoch 192/200
# 141/141 [==============================] - 17s 118ms/step - loss: 0.0013
#
# ----- Generating text after Epoch: 191
# ----- Generating with seed: "to be crossd prison my heart in thy stee"
# to be crossd prison my heart in thy steel doth live when the mentle given thee t
# Epoch 193/200
# 141/141 [==============================] - 16s 117ms/step - loss: 0.0012
#
# ----- Generating text after Epoch: 192
# ----- Generating with seed: "h thee how to make him seem long hence a"
# h thee how to make him seem long hence afay mind so longsur loves roce for me so
# Epoch 194/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.0010
#
# ----- Generating text after Epoch: 193
# ----- Generating with seed: "he spite of fortune make me bow and do n"
# he spite of fortune make me bow and do not do the wnere yet in the basts co pour
# Epoch 195/200
# 141/141 [==============================] - 16s 116ms/step - loss: 9.2299e-04
#
# ----- Generating text after Epoch: 194
# ----- Generating with seed: " me more nearly loving offenders thus i "
#  me more nearly loving offenders thus i amy voon the tende thou shame that which
# Epoch 196/200
# 141/141 [==============================] - 16s 117ms/step - loss: 8.2264e-04
#
# ----- Generating text after Epoch: 195
# ----- Generating with seed: " true mind thus maketh mine untrue or wh"
#  true mind thus maketh mine untrue or why can thy sweet thou manst that my myal
# Epoch 197/200
# 141/141 [==============================] - 16s 115ms/step - loss: 7.3805e-04
#
# ----- Generating text after Epoch: 196
# ----- Generating with seed: " my dear times waste then can i drown an"
#  my dear times waste then can i drown and stande is truths in i nove hoursntated
# Epoch 198/200
# 141/141 [==============================] - 16s 117ms/step - loss: 6.6261e-04
#
# ----- Generating text after Epoch: 197
# ----- Generating with seed: "e by selfexample mayst thou be denied lo"
# e by selfexample mayst thou be denied love and that this thee in the words of th
# Epoch 199/200
# 141/141 [==============================] - 16s 116ms/step - loss: 6.0722e-04
#
# ----- Generating text after Epoch: 198
# ----- Generating with seed: " myself alone and to be sure that is not"
#  myself alone and to be sure that is not fight if maich ot are an verye which in
# Epoch 200/200
# 141/141 [==============================] - 16s 116ms/step - loss: 5.5346e-04
#
# ----- Generating text after Epoch: 199
# ----- Generating with seed: "eated by adding one thing to my purpose "
# eated by adding one thing to my purpose nor my streng have that this which thine

# %%
# save trained model to file 
model.save("trained_text_gen_model200.h5")

# %% [markdown]
# ### Let's Play With Our Trained Model
#
# Now that we have a trained model that, though far from perfect, can generate actual English words, we can look at the predictions to continue learning more about how a text generation model works.
#
# We can also take this as an opportunity to unpack the `def on_epoch_end` function to understand better how it works.

# %%
# this is our joined clean sonnet data
text

# %%
# randomly pick a starting index 
# will be used to take a random sequence of chars from `text`
# run this cell a few times and you'll see `start_index` is random
start_index = random.randint(0, len(text) - dctk.maxlen - 1)
start_index
# Out:
# 59429

# %%
# next use the randomly selected starting index to sample a sequence from the `text`

# this is our seed string (i.e., input sequence into the model)
generated = ''

# start the sentence at index `start_index` and include the next` dctk.maxlen` number of chars
sentence = text[start_index: start_index + dctk.maxlen]

# add to generated
generated += sentence

generated
# Out:
# 'm long hence as he shows now my love is '

# %%
# this block of code lets us know what the seed string is 
# i.e., the input sequence into the model
print('----- Generating with seed: "' + sentence + '"')
sys.stdout.write(generated)
# Out:
# ----- Generating with seed: "m long hence as he shows now my love is "
# m long hence as he shows now my love is
# 40

# %%
# use model to predict what the next 40 chars should be that follow the seed string
for i in range(40):

    # shape of a single sample in a rank 3 tensor 
    x_dims = (1, dctk.maxlen, dctk.n_features)
    # create an array of zeros with shape x_dims
    # recall that python considers zeros and boolean FALSE as the same
    x_pred = np.zeros(x_dims)

    # create a seq vector for our randomly select sequence 
    # i.e. create a numerical encoding for each char in the sequence 
    for t, char in enumerate(sentence):
        # for sample 0 in seq index t and character `char` encode a 1 (which is the same as a TRUE)
        x_pred[0, t, dctk.char_int[char]] = 1

    # next, take the seq vector and pass into model to get a prediction of what the next char should be 
    preds = model.predict(x_pred, verbose=0)[0]
    # use the sample helper function to get index for next char 
    next_index = sample(preds)
    # use look up dict to get next char 
    next_char = dctk.int_char[next_index]

    # append next char to sequence 
    sentence = sentence[1:] + next_char

# %%
# this is the seed string
generated
# Out:
# 'm long hence as he shows now my love is '

# %%
# these are the 40 chars that the model thinks should come after the seed stirng
sentence
# Out:
# 'thy figuting me of should hath my crues '

# %%
# how put it all together
generated + sentence
# Out:
# 'm long hence as he shows now my love is thy figuting me of should hath my crues '

# %% [markdown]
# # Resources and Stretch Goals

# %% [markdown]
# ## Stretch Goals:
# - Refine the training and generation of text to be able to ask for different genres/styles of Shakespearean text (e.g., plays versus sonnets)
# - Train a classification model that takes text and returns which work of Shakespeare it is most likely to be from
# - Make it more performant! Many possible routes here - lean on Keras, optimize the code, and/or use more resources (AWS, etc.)
# - Revisit the news example from class, and improve it - use categories or tags to refine the model/generation, or train a news classifier
# - Run on bigger, better data
#
# ## Resources:
# - [The Unreasonable Effectiveness of Recurrent Neural Networks](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) - a seminal writeup demonstrating a simple but effective character-level NLP RNN
# - [Simple NumPy implementation of RNN](https://github.com/JY-Yoon/RNN-Implementation-using-NumPy/blob/master/RNN%20Implementation%20using%20NumPy.ipynb) - Python 3 version of the code from "Unreasonable Effectiveness"
# - [TensorFlow RNN Tutorial](https://www.tensorflow.org/text/tutorials/text_generation) - code for training an RNN on the Penn Tree Bank language dataset
# - [4 part tutorial on RNN](http://www.wildml.com/2015/09/recurrent-neural-networks-tutorial-part-1-introduction-to-rnns/) - relates RNN to the vanishing gradient problem and provides an example implementation
# - [RNN training tips and tricks](https://github.com/karpathy/char-rnn#tips-and-tricks) - some rules of thumb for parameterizing and training your RNN
